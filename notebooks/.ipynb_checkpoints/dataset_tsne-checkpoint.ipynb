# %%
import torch
from torchvision.datasets import CIFAR10, CIFAR100, SVHN
import numpy as np
import matplotlib.pyplot as pyplot
import torch
import tqdm
import sys
sys.path.append('..')

from models.resnet import resnet32x4
from torchvision.datasets import CIFAR100, CIFAR10, ImageFolder
from torchvision import transforms
from torch.utils.data import DataLoader
from datasets.cifar100 import CIFAR100Gen
# from tsne_pytorch

# %%
# !nvidia-smi
# Out:
# Fri Dec  3 19:32:13 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.67       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:04:00.0 Off |                  N/A |
# | 72%   65C    P2   342W / 350W |  17709MiB / 24268MiB |     98%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:05:00.0 Off |                  N/A |
# | 30%   34C    P8    16W / 350W |      2MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 3090    Off  | 00000000:08:00.0 Off |                  N/A |
# | 30%   26C    P8     5W / 350W |      2MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 3090    Off  | 00000000:09:00.0 Off |                  N/A |
# | 30%   30C    P8    21W / 350W |      2MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce RTX 3090    Off  | 00000000:84:00.0 Off |                  N/A |
# | 30%   28C    P8     7W / 350W |      2MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce RTX 3090    Off  | 00000000:85:00.0 Off |                  N/A |
# | 77%   72C    P2   346W / 350W |  20163MiB / 24268MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce RTX 3090    Off  | 00000000:89:00.0 Off |                  N/A |
# | 35%   47C    P2   108W / 350W |   2483MiB / 24268MiB |      5%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     14885      C   python                          17707MiB |
# |    5   N/A  N/A     45715      C   python                          20161MiB |
# |    6   N/A  N/A     21923      C   python                           2481MiB |
# +-----------------------------------------------------------------------------+

# %%
def load_data(root, dataset='cifar10', gen=False):
    test_transform = transforms.Compose([
        transforms.ToTensor(),
    ])
    if gen:
        test_set = CIFAR100Gen(root=root, transform=test_transform, return_target=True)
    else:
        if dataset == 'cifar10':
            test_set = CIFAR10(root=root, download=True, transform=test_transform)
        elif dataset == 'svhn':
            test_set = SVHN(root=root, download=True, split='test', transform=test_transform)
        elif dataset == 'cifar100':
            test_set = CIFAR100(root=root, download=True, train=False, transform=test_transform)

    test_loader = DataLoader(test_set,
                             batch_size=250,
                             shuffle=False,
                             num_workers=1)
    return test_loader

# %%
class Option:
    def __init__(self, xfile, yfile, resume='', cuda=True):
        self.xfile = xfile
        self.yfile = yfile
        self.resume = resume
        self.cuda = cuda

# %%
# !ls ../save/student_model/resnet28x10_cifar100_lr_0.0002_decay_0_buffer_size_50000_lpx_1.0_lpxy_0.0_energy_mode_mcmc_step_size_1_g_steps_20_trial_4
# Out:
# best.txt	 img_samples	pxy_energy.npy	res_epoch_80.pts
# hyper		 log.txt	qx_energy.npy	sample_10_perclass.png
# img_sample_eval  px_energy.npy	qxy_energy.npy

# %%
opt = Option(xfile='/data/lijingru/cifar100/', yfile='', resume='/data/lijingru/EBKD/save/models/resnet32x4_vanilla/ckpt_epoch_240.pth')

# opt = Option(xfile='/data/lijingru/svhn/', yfile='', resume='/data/lijingru/EBKD/save/models/resnet32x4_vanilla/ckpt_epoch_240.pth')
if opt.cuda:
    print("set use cuda")
    device = 'cuda:4'
#     torch.set_default_tensor_type(torch.cuda.DoubleTensor)
# else:
#     torch.set_default_tensor_type(torch.DoubleTensor)
# Out:
# set use cuda

# %%
def Hbeta_torch(D, beta=1.0):
    
    P = torch.exp(-D.clone() * beta)

    sumP = torch.sum(P)

    H = torch.log(sumP) + beta * torch.sum(D * P) / sumP
    P = P / sumP
    if torch.isnan(P).any() or torch.isnan(H).any():
        print(D)
        print(sumP)
        print(H)
        print(P)
        exit(-1)

    return H, P


def x2p_torch(X, tol=1e-5, perplexity=30.0):
    """
        Performs a binary search to get P-values in such a way that each
        conditional Gaussian has the same perplexity.
    """

    # Initialize some variables
    print("Computing pairwise distances...")
    (n, d) = X.shape
    # print(X)
    # X = torch.tanh(X)s
    sum_X = torch.mean(X*X, 1)
    D = torch.add(torch.add(-2 * torch.mm(X, X.t() / d), sum_X).t(), sum_X)

    P = torch.zeros(n, n).to(device)
    beta = torch.ones(n, 1).to(device)
    logU = torch.log(torch.tensor([perplexity])).to(device)
    n_list = [i for i in range(n)]

    # Loop over all datapoints
    for i in range(n):

        # Print progress
        if i % 200 == 0:
            print("Computing P-values for point %d of %d..." % (i, n))

        # Compute the Gaussian kernel and entropy for the current precision
        # there may be something wrong with this setting None
        betamin = None
        betamax = None
        Di = D[i, n_list[0:i]+n_list[i+1:n]]

        (H, thisP) = Hbeta_torch(Di, beta[i])
        # print(torch.isnan(thisP).any())

        # Evaluate whether the perplexity is within tolerance
        Hdiff = H - logU
        tries = 0
        while torch.abs(Hdiff) > tol and tries < 50:

            # If not, increase or decrease precision
            if Hdiff > 0:
                betamin = beta[i].clone()
                if betamax is None:
                    beta[i] = beta[i] * 2.
                else:
                    beta[i] = (beta[i] + betamax) / 2.
            else:
                betamax = beta[i].clone()
                if betamin is None:
                    beta[i] = beta[i] / 2.
                else:
                    beta[i] = (beta[i] + betamin) / 2.

            # Recompute the values
            (H, thisP) = Hbeta_torch(Di, beta[i])
            # print(torch.isnan(thisP).any())

            Hdiff = H - logU
            tries += 1

        # Set the final row of P
        P[i, n_list[0:i]+n_list[i+1:n]] = thisP

    # Return final P-matrix
    return P


def pca_torch(X, no_dims=50):
    print("Preprocessing the data using PCA...")
    (n, d) = X.shape
    X = X - torch.mean(X, 0)

    (l, M) = torch.eig(torch.mm(X.t(), X), True)
    # split M real
    for i in range(d-1):
        if l[i, 1] != 0:
            M[:, i+1] = M[:, i]
            i += 1

    Y = torch.mm(X, M[:, 0:no_dims])
    return Y


def tsne(X, no_dims=2, initial_dims=50, perplexity=30.0, init_Y=None):
    """
        Runs t-SNE on the dataset in the NxD array X to reduce its
        dimensionality to no_dims dimensions. The syntaxis of the function is
        `Y = tsne.tsne(X, no_dims, perplexity), where X is an NxD NumPy array.
    """

    # Check inputs
    if isinstance(no_dims, float):
        print("Error: array X should not have type float.")
        return -1
    if round(no_dims) != no_dims:
        print("Error: number of dimensions should be an integer.")
        return -1

    # Initialize variables
    X = pca_torch(X, initial_dims)
    (n, d) = X.shape
    max_iter = 5000
    initial_momentum = 0.5
    final_momentum = 0.8
    eta = 500
    min_gain = 0.01
    Y = torch.randn(n, no_dims).to(device) if init_Y is None else torch.FloatTensor(init_Y).to(device)
    dY = torch.zeros(n, no_dims).to(device)
    iY = torch.zeros(n, no_dims).to(device)
    gains = torch.ones(n, no_dims).to(device)

    # Compute P-values
    P = x2p_torch(X, 1e-5, perplexity)
    # print(torch.isnan(P).any())
    P = P + P.t()
    # print(torch.isnan(P).any())
    P = P / torch.sum(P)
    # print(torch.isnan(P).any())
    P = P * 4.    # early exaggeration
    print("get P shape", P.shape)
    P = torch.max(P, torch.Tensor([1e-21]).to(device))
    

    # Run iterations
    for iter in range(max_iter):

        # Compute pairwise affinities
        sum_Y = torch.sum(Y*Y, 1)
        num = -2. * torch.mm(Y, Y.t())
        num = 1. / (1. + torch.add(torch.add(num, sum_Y).t(), sum_Y))
        num[range(n), range(n)] = 0.
        Q = num / torch.sum(num)
        Q = torch.max(Q,torch.Tensor([1e-12]).to(device))

        # Compute gradient
        PQ = P - Q
        for i in range(n):
            dY[i, :] = torch.sum((PQ[:, i] * num[:, i]).repeat(no_dims, 1).t() * (Y[i, :] - Y), 0)

        # Perform the update
        if iter < 20:
            momentum = initial_momentum
        else:
            momentum = final_momentum

        gains = (gains + 0.2) * ((dY > 0.) != (iY > 0.)).double() + (gains * 0.8) * ((dY > 0.) == (iY > 0.)).double()
        gains[gains < min_gain] = min_gain
        iY = momentum * iY - eta * (gains * dY)
        Y = Y + iY
        Y = Y - torch.mean(Y, 0)
        # print('Q:')
        # print(torch.isnan(P).any(), torch.isnan(Q).any())
        if torch.isnan(P).any() or torch.isnan(Q).any():
            exit(-1)
        # Compute current value of cost function
        if (iter + 1) % 100 == 0:
            C = torch.sum(P * torch.log(P / Q))
            print("Iteration %d: error is %f" % (iter + 1, C))

        # Stop lying about P-values
        if iter == 100:
            P = P / 4.

    # Return solution
    return Y

# %%
print("Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.")
torch.multiprocessing.set_start_method('spawn')


# X = np.loadtxt(xfile)
# X = torch.Tensor(X)
# labels = np.loadtxt(yfile).tolist()
test_loader = load_data(opt.xfile, 'cifar100')
X = torch.zeros(len(test_loader.dataset), 100)
# feats = [[], [], [], [], []]
labels = []
Y = []
model = resnet32x4(num_classes=100, norm='batch')
model.to(device)
model.load_state_dict(torch.load(opt.resume, map_location=device)["model"])
model.eval()
for i, data in tqdm.tqdm(enumerate(test_loader)):
    # print('{} / {}'.format(i, len(test_loader)))
    x, y = data[0], data[1]
    x = x.to(device)
    with torch.no_grad():
        feat, out = model(x, is_feat=True)
    # for j in range(5):
    #     feats[j].append(feat[j].view(feats[j].shape[0], -1))
    # x = x.view(x.shape[0], -1).cuda()
    # X.append(out)
        X[i*250:(i+1)*250, :] = out.cpu()
    # print(X.device)
    # print(x.device)
    # with torch.no_grad():
    #     ys = tsne(x, 2, 100, 20.0)
    # Y.append(ys)
    labels.append(y)
# X = torch.cat(X, 0)
# for i in range(5):
#     feats[j] = torch.cat(feats[j], 0)
# Y = torch.cat(Y, 0)
# X = torch.cat(X, 0)
labels = torch.cat(labels, 0)

# confirm that x file get same number point than label file
# otherwise may cause error in scatter
assert(len(X[:, 0])==len(X[:,1]))
assert(len(X)==len(labels))

batch_size = 8192
batches = len(X) // batch_size
Y = []

with torch.no_grad():
    for i in range(batches+1):
        print('*********batches {} / {} **************'.format(i+1, batches+1))
        end = len(X) if i == batches else (i+1)*batch_size
        x = X[i*batch_size:end]
#         y = Y_res[i*batch_size:end]
        y = tsne(x.to(device), 2, 100, 20.0)
        Y.append(y.cpu())
    Y = torch.cat(Y, 0)
#    Y = tsne(X.to(device), 2, 100, 20.0)

if opt.cuda:
    Y = Y.cpu().numpy()
    labels = labels.cpu().numpy()
# You may write result in two files
# print("Save Y values in file")
# Y1 = open("y1.txt", 'w')
# Y2 = open('y2.txt', 'w')
# for i in range(Y.shape[0]):
#     Y1.write(str(Y[i,0])+"\n")
#     Y2.write(str(Y[i,1])+"\n")
# Out:
# Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.
# Files already downloaded and verified
# 40it [00:02, 15.56it/s]
# *********batches 1 / 2 **************
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 8192...
# Computing P-values for point 200 of 8192...
# Computing P-values for point 400 of 8192...
# Computing P-values for point 600 of 8192...
# Computing P-values for point 800 of 8192...
# Computing P-values for point 1000 of 8192...
# Computing P-values for point 1200 of 8192...
# Computing P-values for point 1400 of 8192...
# Computing P-values for point 1600 of 8192...
# Computing P-values for point 1800 of 8192...
# Computing P-values for point 2000 of 8192...
# Computing P-values for point 2200 of 8192...
# Computing P-values for point 2400 of 8192...
# Computing P-values for point 2600 of 8192...
# Computing P-values for point 2800 of 8192...
# Computing P-values for point 3000 of 8192...
# Computing P-values for point 3200 of 8192...
# Computing P-values for point 3400 of 8192...
# Computing P-values for point 3600 of 8192...
# Computing P-values for point 3800 of 8192...
# Computing P-values for point 4000 of 8192...
# Computing P-values for point 4200 of 8192...
# Computing P-values for point 4400 of 8192...
# Computing P-values for point 4600 of 8192...
# Computing P-values for point 4800 of 8192...
# Computing P-values for point 5000 of 8192...
# Computing P-values for point 5200 of 8192...
# Computing P-values for point 5400 of 8192...
# Computing P-values for point 5600 of 8192...
# Computing P-values for point 5800 of 8192...
# Computing P-values for point 6000 of 8192...
# Computing P-values for point 6200 of 8192...
# Computing P-values for point 6400 of 8192...
# Computing P-values for point 6600 of 8192...
# Computing P-values for point 6800 of 8192...
# Computing P-values for point 7000 of 8192...
# Computing P-values for point 7200 of 8192...
# Computing P-values for point 7400 of 8192...
# Computing P-values for point 7600 of 8192...
# Computing P-values for point 7800 of 8192...
# Computing P-values for point 8000 of 8192...
# get P shape torch.Size([8192, 8192])
# Iteration 100: error is 22.444089
# Iteration 200: error is 2.670995
# Iteration 300: error is 2.337425
# Iteration 400: error is 2.184089
# Iteration 500: error is 2.096538
# Iteration 600: error is 2.040128
# Iteration 700: error is 2.001806
# Iteration 800: error is 1.974060
# Iteration 900: error is 1.953289
# Iteration 1000: error is 1.936990
# Iteration 1100: error is 1.924141
# Iteration 1200: error is 1.913766
# Iteration 1300: error is 1.905192
# Iteration 1400: error is 1.898102
# Iteration 1500: error is 1.892138
# Iteration 1600: error is 1.887057
# Iteration 1700: error is 1.882683
# Iteration 1800: error is 1.878906
# Iteration 1900: error is 1.875605
# Iteration 2000: error is 1.872720
# Iteration 2100: error is 1.870217
# Iteration 2200: error is 1.867984
# Iteration 2300: error is 1.865987
# Iteration 2400: error is 1.864195
# Iteration 2500: error is 1.862577
# Iteration 2600: error is 1.861118
# Iteration 2700: error is 1.859789
# Iteration 2800: error is 1.858513
# Iteration 2900: error is 1.857383
# Iteration 3000: error is 1.856389
# Iteration 3100: error is 1.855471
# Iteration 3200: error is 1.854618
# Iteration 3300: error is 1.853826
# Iteration 3400: error is 1.853090
# Iteration 3500: error is 1.852404
# Iteration 3600: error is 1.851763
# Iteration 3700: error is 1.851163
# Iteration 3800: error is 1.850598
# Iteration 3900: error is 1.850030
# Iteration 4000: error is 1.849391
# Iteration 4100: error is 1.848931
# Iteration 4200: error is 1.848493
# Iteration 4300: error is 1.848074
# Iteration 4400: error is 1.847675
# Iteration 4500: error is 1.847295
# Iteration 4600: error is 1.846930
# Iteration 4700: error is 1.846581
# Iteration 4800: error is 1.846246
# Iteration 4900: error is 1.845915
# Iteration 5000: error is 1.845600
# *********batches 2 / 2 **************
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 1808...
# Computing P-values for point 200 of 1808...
# Computing P-values for point 400 of 1808...
# Computing P-values for point 600 of 1808...
# Computing P-values for point 800 of 1808...
# Computing P-values for point 1000 of 1808...
# Computing P-values for point 1200 of 1808...
# Computing P-values for point 1400 of 1808...
# Computing P-values for point 1600 of 1808...
# Computing P-values for point 1800 of 1808...
# get P shape torch.Size([1808, 1808])
# Iteration 100: error is 18.606672
# Iteration 200: error is 1.500768
# Iteration 300: error is 1.378272
# Iteration 400: error is 1.341903
# Iteration 500: error is 1.326836
# Iteration 600: error is 1.319224
# Iteration 700: error is 1.314760
# Iteration 800: error is 1.311910
# Iteration 900: error is 1.309961
# Iteration 1000: error is 1.308550
# Iteration 1100: error is 1.307488
# Iteration 1200: error is 1.306658
# Iteration 1300: error is 1.305994
# Iteration 1400: error is 1.305447
# Iteration 1500: error is 1.304989
# Iteration 1600: error is 1.304597
# Iteration 1700: error is 1.304257
# Iteration 1800: error is 1.303963
# Iteration 1900: error is 1.303704
# Iteration 2000: error is 1.303473
# Iteration 2100: error is 1.303266
# Iteration 2200: error is 1.303078
# Iteration 2300: error is 1.302907
# Iteration 2400: error is 1.302751
# Iteration 2500: error is 1.302608
# Iteration 2600: error is 1.302475
# Iteration 2700: error is 1.302352
# Iteration 2800: error is 1.302238
# Iteration 2900: error is 1.302132
# Iteration 3000: error is 1.302032
# Iteration 3100: error is 1.301939
# Iteration 3200: error is 1.301851
# Iteration 3300: error is 1.301768
# Iteration 3400: error is 1.301689
# Iteration 3500: error is 1.301614
# Iteration 3600: error is 1.301543
# Iteration 3700: error is 1.301476
# Iteration 3800: error is 1.301412
# Iteration 3900: error is 1.301351
# Iteration 4000: error is 1.301292
# Iteration 4100: error is 1.301236
# Iteration 4200: error is 1.301183
# Iteration 4300: error is 1.301131
# Iteration 4400: error is 1.301082
# Iteration 4500: error is 1.301034
# Iteration 4600: error is 1.300989
# Iteration 4700: error is 1.300945
# Iteration 4800: error is 1.300902
# Iteration 4900: error is 1.300861
# Iteration 5000: error is 1.300822

# %%
np.save('nowY_gen.npy', Y)
np.save('nowlabels_gen.npy', labels)

# %%
Y_res = np.load('nowY.npy')
labels_res = np.load('nowlabels.npy')

# %%
pyplot.scatter(Y[:, 0], Y[:, 1], c=labels)
pyplot.xlabel('Component 1')
pyplot.ylabel('Component 2')
pyplot.show()
