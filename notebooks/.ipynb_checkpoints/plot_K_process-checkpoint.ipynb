# %%
import seaborn as sns
import torch
import numpy as np
import json

# %% [markdown]
# ### Choose the root of KD
# Find the original root directory of KD.

# %%
# !ls ../save/student_datafree_model/
# Out:
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.01_a:0.99_b:0.0_0_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.01_a:0.99_b:0.0_1_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.01_a:0.99_b:0.0_2_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.01_a:0.99_b:0.0_3_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.01_a:0.99_b:0.0_4_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.01_a:0.99_b:0.0_5_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.01_a:0.99_b:0.0_6_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.01_a:0.99_b:0.0_7_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.01_a:0.99_b:0.0_8_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.01_a:0.99_b:0.0_9_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_0_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_0_df_30000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_0_df_40000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_0_df_50000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_0_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_1_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_1_df_30000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_1_df_40000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_1_df_50000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_1_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_2_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_2_df_30000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_2_df_40000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_2_df_50000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_2_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_3_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_3_df_30000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_3_df_40000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_3_df_50000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_3_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_4_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_4_df_30000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_4_df_40000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_4_df_50000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_4_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_5_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_5_df_30000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_5_df_40000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_5_df_50000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_5_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_6_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_6_df_30000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_6_df_40000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_6_df_50000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_6_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_7_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_7_df_30000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_7_df_40000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_7_df_50000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_7_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_8_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_8_df_30000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_8_df_40000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_8_df_50000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_8_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_9_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_9_df_30000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_9_df_40000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_9_df_50000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_9_vae_lc_2
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_0_5000_g_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_0_deepinv
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_0_k_10_3000_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_0_k_10_3000_120
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_0_k_10_3000_150
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_0_k_10_5000_50
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_0_k_10_5000_70
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_0_k_10_5000_80
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_0_k_rr
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_0_vae
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_0_vae_lc
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_1_5000_g_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_1_deepinv
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_1_k_10_3000_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_1_k_10_3000_120
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_1_k_10_3000_150
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_1_k_10_5000_50
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_1_k_10_5000_70
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_1_k_10_5000_80
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_1_vae
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_1_vae_lc
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_2_5000_g_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_2_deepinv
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_2_k_10_3000_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_2_k_10_3000_120
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_2_k_10_3000_150
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_2_k_10_5000_50
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_2_k_10_5000_70
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_2_k_10_5000_80
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_2_vae
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_2_vae_lc
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_3_5000_g_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_3_deepinv
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_3_k_10_3000_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_3_k_10_3000_120
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_3_k_10_3000_150
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_3_k_10_5000_50
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_3_k_10_5000_70
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_3_k_10_5000_80
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_3_vae
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_3_vae_lc
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_4_5000_g_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_4_deepinv
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_4_k_10_3000_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_4_k_10_3000_120
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_4_k_10_3000_150
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_4_k_10_5000_50
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_4_k_10_5000_70
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_4_k_10_5000_80
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_4_vae
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_4_vae_lc
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_5_5000_g_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_5_k_10_3000_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_5_k_10_3000_120
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_5_k_10_3000_150
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_5_k_10_5000_50
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_5_k_10_5000_70
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_5_k_10_5000_80
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_5_vae
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_5_vae_lc
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_6_5000_g_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_6_k_10_3000_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_6_k_10_3000_120
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_6_k_10_3000_150
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_6_k_10_5000_50
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_6_k_10_5000_70
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_6_k_10_5000_80
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_6_vae
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_6_vae_lc
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_7_5000_g_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_7_k_10_3000_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_7_k_10_3000_150
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_7_k_10_5000_50
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_7_k_10_5000_70
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_7_k_10_5000_80
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_7_vae
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_7_vae_lc
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_8_5000_g_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_8_k_10_3000_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_8_k_10_3000_150
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_8_k_10_5000_50
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_8_k_10_5000_70
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_8_k_10_5000_80
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_8_vae
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_8_vae_lc
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_9_5000_g_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_9_k_10_3000_100
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_9_k_10_3000_150
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_9_k_10_5000_50
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_9_k_10_5000_70
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_9_k_10_5000_80
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_9_vae
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0_9_vae_lc
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.3_a:0.7_b:0.0__k_10_x
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_0_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_0_k_1
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_0_K_10
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_0_k_10_all
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_0_k_10_xy
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_0_k_3
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_0_k_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_0_k_5_False
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_0_k_5_random
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_0_k_5_st_0
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_0_k_5_st_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_0_k_7
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_1_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_1_k_1
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_1_K_10
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_1_k_10_all
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_1_k_10_xy
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_1_k_3
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_1_k_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_1_k_5_False
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_1_k_5_random
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_1_k_5_st_0
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_1_k_5_st_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_1_k_7
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_2_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_2_k_1
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_2_K_10
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_2_k_10_all
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_2_k_10_xy
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_2_k_3
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_2_k_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_2_k_5_False
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_2_k_5_random
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_2_k_5_st_0
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_2_k_5_st_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_2_k_7
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_3_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_3_k_1
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_3_K_10
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_3_k_10_all
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_3_k_10_xy
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_3_k_3
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_3_k_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_3_k_5_False
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_3_k_5_random
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_3_k_5_st_0
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_3_k_5_st_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_3_k_7
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_4_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_4_k_1
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_4_K_10
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_4_k_10_xy
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_4_k_3
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_4_k_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_4_k_5_False
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_4_k_5_random
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_4_k_5_st_0
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_4_k_5_st_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_4_k_7
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_5_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_5_k_1
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_5_K_10
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_5_k_10_xy
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_5_k_3
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_5_k_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_5_k_5_False
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_5_k_5_random
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_5_k_5_st_0
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_5_k_5_st_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_5_k_7
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_6_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_6_k_1
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_6_K_10
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_6_k_10_xy
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_6_k_3
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_6_k_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_6_k_5_False
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_6_k_5_random
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_6_k_5_st_0
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_6_k_5_st_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_6_k_7
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_7_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_7_k_1
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_7_K_10
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_7_k_10_xy
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_7_k_3
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_7_k_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_7_k_5_False
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_7_k_5_random
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_7_k_5_st_0
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_7_k_5_st_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_7_k_7
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_8_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_8_k_1
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_8_K_10
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_8_k_10_xy
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_8_k_3
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_8_k_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_8_k_5_False
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_8_k_5_random
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_8_k_5_st_0
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_8_k_5_st_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_8_k_7
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_9_df_10000
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_9_k_1
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_9_K_10
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_9_k_10_xy
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_9_k_3
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_9_k_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_9_k_5_False
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_9_k_5_random
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_9_k_5_st_0
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_9_k_5_st_5
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0_9_k_7
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0__k_10_x
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.4_a:0.6_b:0.0__k_7_xy0
# S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.5_a:0.5_b:0.0_0_df_10000
# S:resnet8x4_T:resnet32x4_svhn_kd_r:0.4_a:0.6_b:0.0_0_k_10
# S:resnet8x4_T:resnet32x4_svhn_kd_r:0.4_a:0.6_b:0.0_1_k_10
# S:resnet8x4_T:resnet32x4_svhn_kd_r:0.4_a:0.6_b:0.0_2_k_10
# S:resnet8x4_T:resnet32x4_svhn_kd_r:0.4_a:0.6_b:0.0_3_k_10
# S:resnet8x4_T:resnet32x4_svhn_kd_r:0.4_a:0.6_b:0.0_4_k_10
# S:resnet8x4_T:resnet32x4_svhn_kd_r:0.4_a:0.6_b:0.0_5_k_10
# S:resnet8x4_T:resnet32x4_svhn_kd_r:0.4_a:0.6_b:0.0_6_k_10
# S:resnet8x4_T:resnet32x4_svhn_kd_r:0.4_a:0.6_b:0.0_7_k_10
# S:resnet8x4_T:resnet32x4_svhn_kd_r:0.4_a:0.6_b:0.0_8_k_10
# S:resnet8x4_T:resnet32x4_svhn_kd_r:0.4_a:0.6_b:0.0_9_k_10
# S:resnet8x4_T:resnet32x4_svhn_kd_r:0.4_a:0.6_b:0.0__k_10

# %%
device = 'cuda:1'
ckpt_res = torch.load('../save/student_datafree_model/S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_6_df_40000/resnet8x4_best.pth', map_location=device)
ckpt_res.keys()

ckpt_teacher = torch.load('/data/lijingru/EBKD/save/models/resnet32x4_vanilla/ckpt_epoch_240.pth', map_location=device)
ckpt_teacher.keys()

ckpt_energy = torch.load('/data/lijingru/EBKD/save/student_model/resnet28x10_cifar100_lr_0.0002_decay_0_buffer_size_40000_lpx_1.0_lpxy_0.0_energy_mode_mcmc_step_size_1_g_steps_20_trial_2/res_epoch_200.pts', map_location=device)
ckpt_energy.keys()
# Out:
# dict_keys(['model_state_dict', 'replay_buffer'])

# %%
import sys
sys.path.append('..')
from models.resnet import resnet8x4, resnet32x4
from models import model_dict

model_score = model_dict['resnet28x10'](num_classes=100, norm='none', depth=28, widen_factor=10)
model_score = model_dict['Gen'](model=model_score, n_cls=100)
model_score.load_state_dict(ckpt_energy['model_state_dict'])
model_score.to(device)
model_score.eval()

model = resnet8x4(num_classes=100, norm='batch')
model = model.to(device)
model.load_state_dict(ckpt_res['model'])
model.eval()

teacher = resnet32x4(num_classes=100, norm='batch')
teacher = teacher.to(device)
teacher.load_state_dict(ckpt_teacher['model'])
teacher.eval()
# Out:
# | Wide-Resnet 28x10
# ResNet(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#   (fc): Linear(in_features=256, out_features=100, bias=True)
# )

# %%
class Option:
    def __init__(self):
        self.device = device
        self.augment = False
        self.short_run = False
        self.g_steps = 40
        self.step_size = 1
        self.batch_size = 256
        self.reinit_freq = 0.05
        self.dataset = 'cifar100'
        self.n_cls = 100
        self.save_dir = './tmp/exp2/'
        self.save_folder = './tmp/'
        self.buffer_size = 40000
        self.save_grid = False

import os
opt = Option()
if not os.path.exists(opt.save_dir):
    os.mkdir(opt.save_dir)

# %%
from helper.sampling import langevin_at_x, init_random
import matplotlib.pyplot as plt
import torchvision.utils as vutils
import tqdm
from helper.util import inception_score
from datasets.cifar100 import CIFAR100Gen
import torchvision.transforms as T
from helper.util_gen import cond_samples


sample_q = langevin_at_x(opts=opt, device=device)
replay_buffer = ckpt_energy['replay_buffer'].cpu()
y = torch.arange(0, opt.n_cls).to(device)

sqrt = lambda x: int(torch.sqrt(torch.Tensor([x])))
plot = lambda x: vutils.make_grid(torch.clamp(x, -1, 1), normalize=True, nrow=sqrt(x.size(0)))

# %%
freshh_epochs = 5001
for i in range(freshh_epochs):
    samples, _ = sample_q(model_score, replay_buffer, y=y)
    if i % 200 == 0:
        print('Epoch {} / {} ****'.format(i, freshh_epochs))
        buffer_size = len(replay_buffer)
        inds = torch.randint(0, buffer_size, (25,))
        sampled = replay_buffer[inds]
        imgs = plot(sampled).cpu()
        img = np.transpose(imgs, (1,2,0))
        plt.figure(10)
        plt.imshow(img)
        replay_buffer = cond_samples(model_score, replay_buffer, device, opt, use_buffer=True)
        test_folder = opt.save_dir
        dataset = CIFAR100Gen(
            root=test_folder,
            transform=T.Compose([
                T.ToTensor(),
                T.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
            ])
        )
        mean, var = inception_score(dataset, device, resize=True, splits=3, batch_size=8)
        print('IS: {} +- {}'.format(mean, var))
# Out:
# Epoch 0 / 5001 ****
#  36%|███▌      | 36/100 [04:59<08:52,  8.33s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6520ea85e66b> in <module>
#      11         plt.figure(10)
#      12         plt.imshow(img)
# ---> 13         replay_buffer = cond_samples(model_score, replay_buffer, device, opt, use_buffer=True)
#      14         test_folder = opt.save_dir
#      15         dataset = CIFAR100Gen(
#
# ~/EBKD/helper/util_gen.py in cond_samples(model, replay_buffer, device, opt, fresh, use_buffer)
#      82             for j, im in enumerate(each_class[i]):
#      83                 output = model(im.unsqueeze(0).to(device))[0].mean()
# ---> 84                 output_xy = model(im.unsqueeze(0).to(device), y=y)[0].mean()
#      85                 # if output < -10 and output_xy < -10:
#      86                 #     continue
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/EBKD/models/generator.py in forward(self, x, y, cls_mode, is_feat, preact, py)
#      76         #print(cls_mode, is_feat, preact, y)
#      77
# ---> 78         feats, logits = super().classify(x, is_feat=True)
#      79         if torch.isnan(logits).any():
#      80             # print(self.f)
#
# ~/EBKD/models/generator.py in classify(self, x, is_feat, preact)
#      48     def classify(self, x, is_feat=False, preact=False):
#      49         if is_feat:
# ---> 50             feats, penult_z = self.f(x, is_feat=is_feat)
#      51             # print(penult_z.shape)
#      52             # print(penult_z.requires_grad)
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/EBKD/models/widerresnet.py in forward(self, x, vx, is_feat, preact)
#     124     def forward(self, x, vx=None, is_feat=False, preact=False):
#     125         f1 = self.conv1(x)
# --> 126         f2 = self.layer1(f1)
#     127         f3 = self.layer2(f2)
#     128         f4 = self.layer3(f3)
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/EBKD/models/widerresnet.py in forward(self, x)
#      65     def forward(self, x):
#      66         # print(self.dropout, self.conv1, self.lrelu, self.bn1)
# ---> 67         out = self.dropout(self.conv1(self.lrelu(self.bn1(x))))
#      68         out = self.conv2(self.lrelu(self.bn2(out)))
#      69         out += self.shortcut(x)
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
# --> 399         return self._conv_forward(input, self.weight, self.bias)
#     400
#     401 class Conv3d(_ConvNd):
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     393                             weight, bias, self.stride,
#     394                             _pair(0), self.dilation, self.groups)
# --> 395         return F.conv2d(input, weight, bias, self.stride,
#     396                         self.padding, self.dilation, self.groups)
#     397
#
# KeyboardInterrupt:

# %%
from torchvision.datasets import CIFAR100
from torchvision import transforms
from torch.utils.data import DataLoader
test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
test_set = CIFAR100(root='/data/lijingru/cifar100', download=False, train=False, transform=test_transform)
test_loader = DataLoader(test_set,
                         batch_size=1,
                         shuffle=False,
                         num_workers=1)

# %%
import tqdm
stu_incorrects = {'probs':[], 'energys':[]}
tea_incorrects = {'probs':[], 'energys':[]}
all_data = {'probs':[], 'energys':[]}

for idx, data in tqdm.tqdm(enumerate(test_loader)):
    x, y = data
    x = x.to(device)
    y = y.to(device)
    y_pred = model(x)
    y_pred_tea = teacher(x)
    energy = model_score(x, y=y)[0]
    all_data['energys'].append(energy.item())
#     all_data['data'].append(x[0].cpu().numpy().tolist())
    all_data['probs'].append(y_pred[0].detach().cpu().numpy().tolist())
    hard_y = y_pred.argmax(1)[0]
    hard_tea_y = y_pred_tea.argmax(1)[0]
#     print(hard_y, hard_tea_y, y)
    if hard_y != y[0]:
#         incorrects['data'].append(x[0].cpu().numpy())
        stu_incorrects['probs'].append(y_pred[0].detach().cpu().numpy().tolist())
        stu_incorrects['energys'].append(energy.item())
    if hard_tea_y != y[0]:
        tea_incorrects['probs'].append(y_pred_tea[0].detach().cpu().numpy().tolist())
        tea_incorrects['energys'].append(energy.item())
        
print('All data: {}'.format(len(all_data['probs'])))
print('Teacher incorrect: {}'.format(len(tea_incorrects['probs'])))
print('Student incorrect: {}'.format(len(stu_incorrects['probs'])))
# Out:
# 10000it [04:27, 37.38it/s]
# All data: 10000
# Teacher incorrect: 2791
# Student incorrect: 4807

# %%
import json
with open('all.json', 'w') as f:
    f.write(json.dumps(all_data, ensure_ascii=False, indent=4, separators=(',', ':')))
    
with open('incorrect_stu.json', 'w') as f:
    f.write(json.dumps(stu_incorrects, ensure_ascii=False, indent=4, separators=(',', ':')))
    
with open('incorrect_tea.json', 'w') as f:
    f.write(json.dumps(tea_incorrects, ensure_ascii=False, indent=4, separators=(',', ':')))

# %% [markdown]
# ### Plot distribution of incorrect samples

# %%
with open('all.json', 'r') as f:
    all_data = json.load(f)
    
with open('incorrect_stu.json') as f:
    stu_incorrects = json.load(f)
    
with open('incorrect_tea.json') as f:
    tea_incorrects = json.load(f)

# %%
import seaborn as sns
sns.kdeplot(data={'all_data': all_data['energys'], 'stu_incorrect': stu_incorrects['energys'], 'tea_incorrect': tea_incorrects['energys']}, clip=(-8, 5), fill=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
logos = ['k_10']
for logo in logos:
    scores = []
    for i in range(10):
        pths = torch.load('save/student_datafree_model/S:resnet8x4_T:resnet32x4_svhn_kd_r:0.4_a:0.6_b:0.0_{}_{}/resnet8x4_best.pth'.format(i, logo))
        acc = pths['best_acc']
        scores.append(acc.item())
    scores = np.asarray(scores)
    print('T:resnet32x4, S:resnet8x4, logo:{},  acc:{} +- {}'.format(logo, np.mean(scores), np.var(scores) ** 0.5))
# Out:
# T:resnet32x4, S:resnet8x4, logo:k_10,  acc:93.28749084472656 +- 0.17234420576255796

# %%
logos = [ 'df_10000', 'df_30000', 'df_40000', 'df_50000']
data = []
for logo in logos:
    scores = []
    for i in range(9):
        pths = torch.load('../save/student_datafree_model/S:resnet8x4_T:resnet32x4_cifar100_kd_r:0.1_a:0.9_b:0.0_{}_{}/resnet8x4_best.pth'.format(i, logo))
        acc = pths['best_acc']
        scores.append(acc.item())
    scores = np.asarray(scores)
    data.append(scores)
    print('T:resnet32x4, S:resnet8x4, logo:{},  acc:{} +- {}'.format(logo, np.mean(scores), np.var(scores) ** 0.5))

data = np.asarray(data)
# Out:
# T:resnet32x4, S:resnet8x4, logo:df_10000,  acc:36.04888788859049 +- 0.584873380242915
# T:resnet32x4, S:resnet8x4, logo:df_30000,  acc:51.28666517469618 +- 1.144833721863551
# T:resnet32x4, S:resnet8x4, logo:df_40000,  acc:52.15777672661675 +- 0.2561582599249095
# T:resnet32x4, S:resnet8x4, logo:df_50000,  acc:55.84888797336154 +- 0.34728977793537

# %%
import pandas as pd
columns = [  'df_10000', 'df_30000', 'df_40000', 'df_50000']
real_data = pd.DataFrame(data=data.T, columns=columns)
real_data
# Out:
#     df_10000   df_30000   df_40000   df_50000
# 0  35.320000  48.099998  52.329998  56.340000
# 1  36.689999  51.270000  52.230000  55.539997
# 2  35.259998  51.699997  52.299999  56.239998
# 3  35.489998  51.759998  52.099998  55.559998
# 4  36.730000  51.579998  52.219997  55.820000
# 5  36.489998  51.879997  52.169998  55.930000
# 6  35.599998  51.789997  51.930000  55.840000
# 7  36.590000  51.500000  51.590000  55.209999
# 8  36.270000  52.000000  52.549999  56.160000

# %%
ax = sns.boxplot(data=real_data)
ax.set_xlabel('Sample Steps')
ax.set_ylabel('Student Acc.')
# Out:
# Text(0, 0.5, 'Student Acc.')
