# %%
import numpy as np
import torch
import cv2
import seaborn as sns

from models import model_dict
from helper.util_gen import get_sample_q

# %% [markdown]
# # Get model and replay buffer

# %%
# !ls save/student_model/resnet28x10_T:resnet32x4_S:resnet8x4_cifar100_lr_0.0001_decay_0.0_buffer_size_10000_lpx_1.0_lpxy_0.0_energy_mode_mcmc_step_size_1.0_trial_cor_random_cls_mode_cls_k_10
# Out:
# img_samples	  res_epoch_65.pts  res_epoch_75.pts
# res_epoch_60.pts  res_epoch_70.pts  res_epoch_80.pts

# %%
# !nvidia-smi
# Out:
# Sat Aug 28 22:31:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.67       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:05:00.0 Off |                  N/A |
# | 74%   66C    P2   346W / 350W |   9482MiB / 24268MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:09:00.0 Off |                  N/A |
# | 73%   66C    P2   318W / 350W |  20261MiB / 24268MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 3090    Off  | 00000000:82:00.0 Off |                  N/A |
# | 57%   61C    P2   323W / 350W |  20261MiB / 24268MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 3090    Off  | 00000000:85:00.0 Off |                  N/A |
# | 67%   63C    P2   319W / 350W |   4825MiB / 24268MiB |     80%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce RTX 3090    Off  | 00000000:89:00.0 Off |                  N/A |
# | 76%   67C    P2   344W / 350W |   5425MiB / 24268MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     40829      C   python                           3775MiB |
# |    0   N/A  N/A     41708      C   python                           5705MiB |
# |    1   N/A  N/A      2900      C   python                          20235MiB |
# |    2   N/A  N/A      2231      C   python                          20235MiB |
# |    3   N/A  N/A     41374      C   python                           4823MiB |
# |    4   N/A  N/A     40742      C   python                           5423MiB |
# +-----------------------------------------------------------------------------+

# %%
import matplotlib.pyplot as plt
import torchvision.utils as vutils
device = "cuda:3"
model = model_dict['resnet28x10'](depth=28, widen_factor=10, num_classes=100, norm='none')
model = model_dict['Gen'](model, n_cls=100)
model = model.to(device)
save_path = '/data/lijingru/EBKD/save/student_model/resnet28x10_T:resnet32x4_S:resnet8x4_cifar100_lr_0.0001_decay_0.0_buffer_size_10000_lpx_1.0_lpxy_0.0_energy_mode_mcmc_step_size_1.0_trial_cor_random_cls_mode_cls_k_10/'
ckpt_dict = torch.load(save_path + 'res_epoch_80.pts', map_location=device)
model.load_state_dict(ckpt_dict["model_state_dict"])
replay_buffer = ckpt_dict["replay_buffer"]
sqrt = lambda x: int(torch.sqrt(torch.tensor([x])))
plot = lambda x: vutils.make_grid(torch.clamp(x, -1, 1), normalize=True, nrow=sqrt(x.size(0)))
buffer_size = len(replay_buffer)
inds = torch.randint(0, buffer_size, (25,))
sampled = replay_buffer[inds]
imgs = plot(sampled).cpu()
img = np.transpose(imgs, (1,2,0))
plt.figure(10)
plt.imshow(img)
# Out:
# | Wide-Resnet 28x10

# %% [markdown]
# ### Calculate Inception Score and Options

# %%
import os
# save_path = '/data/lijingru/EBKD/save/student_model/resnet8x4_cifar100_lr_0.0001_decay_0.0_buffer_size_40000_lpx_0.0_lpxy_1.0_energy_mode_mcmc_step_size_5.0_trial_2_cls/'
if not os.path.exists(save_path):
    os.mkdir(save_path)



class Options:
    def __init__(self, save_grid=False):
        self.n_cls = 100
        self.save_folder = save_path
        if not save_grid:
            self.save_dir = os.path.join(save_path, 'img_sample_eval/')
        else:
            self.save_dir = os.path.join(save_path, 'img_sample_eval_grid/')
        self.save_grid = save_grid
        self.reinit_freq = 0.05
        self.batch_size = 64
        self.step_size = 1
        self.buffer_size = 10000
        self.n_sample_steps = 5
        self.print_every = 100
        self.dataset = 'cifar100'
        self.g_steps = 40
#         self.reinit_freq = 0.
        if not os.path.exists(self.save_dir):
            os.mkdir(self.save_dir)

        
opt = Options()

replay_buffer.size(0) / opt.n_cls
# Out:
# 100.0

# %% [markdown]
# ## Visualize sample q
# The visualization of $x \sim q_{\theta}$.

# %%
from helper.util_gen import get_sample_q

sample_q, _ = get_sample_q(opt)
f_sample, samples = sample_q(model, replay_buffer, open_debug=True)
samples = torch.cat(samples, 0).cpu()
imgs = plot(samples)
img = np.transpose(imgs, (1,2,0))
plt.figure(10)
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-ffafc85d8f4d> in <module>
#       2
#       3 sample_q, _ = get_sample_q(opt)
# ----> 4 f_sample, samples = sample_q(model, replay_buffer, open_debug=True)
#       5 samples = torch.cat(samples, 0).cpu()
#       6 imgs = plot(samples)
#
# ~/EBKD/helper/util_gen.py in sample_q(f, replay_buffer, y, n_steps, open_debug, open_clip_grad)
#     195         x_k_pre = init_sample
#     196         for k in range(n_steps):
# --> 197             f_prime = torch.autograd.grad(f(x_k, y=y)[0].sum(), [x_k], retain_graph=True)[0]
#     198             noise = 0.01 * torch.randn_like(x_k)
#     199             x_k = x_k + now_step_size * f_prime + noise
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/EBKD/models/generator.py in forward(self, x, y, cls_mode, is_feat, preact, py)
#      75         #print(cls_mode, is_feat, preact, y)
#      76
# ---> 77         feats, logits = super().classify(x, is_feat=True, preact=preact)
#      78
#      79         # feat = feats[-1]
#
# ~/EBKD/models/generator.py in classify(self, x, is_feat, preact)
#      48     def classify(self, x, is_feat=False, preact=False):
#      49         if is_feat:
# ---> 50             feats, penult_z = self.f(x, is_feat=is_feat, preact=preact)
#      51             # print(penult_z.requires_grad)
#      52             # print(self.f(x, is_feat=is_feat, preact=preact))
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/EBKD/models/widerresnet.py in forward(self, x, vx, is_feat, preact)
#     113
#     114     def forward(self, x, vx=None, is_feat=False, preact=False):
# --> 115         f1 = self.conv1(x)
#     116         f2 = self.layer1(f1)
#     117         f3 = self.layer2(f2)
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
# --> 399         return self._conv_forward(input, self.weight, self.bias)
#     400
#     401 class Conv3d(_ConvNd):
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     393                             weight, bias, self.stride,
#     394                             _pair(0), self.dilation, self.groups)
# --> 395         return F.conv2d(input, weight, bias, self.stride,
#     396                         self.padding, self.dilation, self.groups)
#     397
#
# RuntimeError: Expected tensor for argument #1 'input' to have the same device as tensor for argument #2 'weight'; but device 0 does not equal 1 (while checking arguments for cudnn_convolution)

# %%
# !rm -rf /data/lijingru/EBKD/save/student_model/resnet28x10_T:resnet32x4_S:resnet8x4_svhn_lr_0.0001_decay_0.0_buffer_size_10000_lpx_1.0_lpxy_0.0_energy_mode_mcmc_step_size_1.0_trial_1_st_random_cls_mode_cls_k_10/img_sample_eval/

# %%
from helper.util_gen import cond_samples
opt = Options()
if not os.path.exists(opt.save_dir):
    os.mkdir(opt.save_dir)
# model.cuda()
cond_samples(model, replay_buffer, device, opt, use_buffer=True)
# Out:
# 100%|██████████| 100/100 [03:32<00:00,  2.12s/it]
# Successfully saving the generated result of replay buffer.
# tensor([[[[ 1.0841,  1.0132,  1.0082,  ...,  1.0669,  1.0236,  1.0874],
#           [ 1.0191,  0.9657,  0.9644,  ...,  1.0445,  0.9959,  1.0593],
#           [ 1.0134,  0.9746,  0.9719,  ...,  0.9722,  0.9752,  1.0727],
#           ...,
#           [ 1.1015,  1.0374,  1.0099,  ...,  0.9885,  1.0512,  0.9624],
#           [ 1.0027,  1.0445,  1.0280,  ...,  0.9892,  0.9499,  1.0353],
#           [ 1.1629,  1.0608,  1.0083,  ...,  0.9629,  1.0512,  0.9801]],
#
#          [[ 1.1011,  0.9726,  0.9975,  ...,  1.0525,  1.0598,  1.0853],
#           [ 1.0229,  1.0010,  0.9520,  ...,  1.0538,  0.9955,  1.0066],
#           [ 0.9459,  1.0726,  0.7070,  ...,  1.0283,  0.9814,  1.0278],
#           ...,
#           [ 1.0695,  1.0480,  0.9829,  ...,  1.0356,  1.0084,  0.9837],
#           [ 0.9837,  0.9797,  1.0196,  ...,  1.0096,  0.9590,  1.0016],
#           [ 1.0581,  0.9595,  0.9750,  ...,  0.9913,  1.0384,  0.9966]],
#
#          [[ 1.0569,  1.0215,  0.9941,  ...,  0.9692,  1.0097,  1.0698],
#           [ 1.0253,  0.9866,  1.0171,  ...,  1.0511,  1.0176,  1.0331],
#           [ 1.0933,  0.9321,  0.7713,  ...,  1.0077,  1.0264,  1.0027],
#           ...,
#           [ 1.0110,  0.9892,  0.9590,  ...,  0.9932,  1.0393,  1.0116],
#           [ 0.9926,  1.0223,  0.9903,  ...,  1.0181,  0.9945,  0.9797],
#           [ 1.0886,  1.0048,  0.9864,  ...,  1.0115,  1.0095,  1.0437]]],
#
#
#         [[[-0.1523, -0.4304, -0.4209,  ..., -0.2937, -0.3285, -0.2806],
#           [ 0.0778, -0.0885, -0.0878,  ..., -0.4416, -0.5192, -0.5500],
#           [ 0.1320,  0.0852,  0.1028,  ..., -0.6995, -0.7234, -0.8515],
#           ...,
#           [-0.9549, -0.9393, -0.9450,  ...,  0.6774,  0.9496,  0.4355],
#           [-0.8899, -1.0365, -0.9045,  ...,  0.6617,  0.6395,  0.3143],
#           [-0.9378, -0.8935, -0.9189,  ...,  0.4146,  0.6235,  0.5519]],
#
#          [[-0.3253, -0.4029, -0.4660,  ..., -0.1798, -0.3218, -0.3296],
#           [ 0.0285, -0.0700, -0.1392,  ..., -0.3280, -0.4589, -0.4505],
#           [ 0.2177,  0.1069,  0.1403,  ..., -0.6132, -0.6759, -0.7092],
#           ...,
#           [-0.9452, -0.8866, -0.9599,  ...,  0.3888,  0.6493,  0.2326],
#           [-0.9715, -0.9526, -0.9726,  ...,  0.2725,  0.2459,  0.0193],
#           [-0.9209, -0.9191, -0.9476,  ...,  0.0144,  0.2255,  0.3592]],
#
#          [[-0.2390, -0.5624, -0.6889,  ..., -0.3783, -0.4795, -0.4238],
#           [ 0.1394, -0.0229, -0.1673,  ..., -0.4400, -0.5111, -0.5943],
#           [ 0.3526,  0.2588,  0.2403,  ..., -0.7363, -0.7918, -0.8253],
#           ...,
#           [-1.0604, -0.9281, -0.9505,  ..., -0.6004, -0.4843, -0.8335],
#           [-0.9837, -0.9654, -0.9710,  ..., -0.8336, -0.6630, -0.9066],
#           [-0.9907, -0.9611, -0.9031,  ..., -0.9593, -0.5652, -0.5554]]],
#
#
#         [[[-0.1154, -0.0187, -0.3170,  ...,  0.2588,  0.1540,  0.1615],
#           [ 0.1053, -0.4810, -0.7995,  ...,  0.2571,  0.2111,  0.1281],
#           [-0.1119, -0.5312, -0.4637,  ...,  0.1285,  0.0579,  0.2301],
#           ...,
#           [-0.4408, -0.1891,  0.0062,  ..., -0.3454, -0.3442, -0.3374],
#           [-0.3454, -0.1858, -0.1492,  ..., -0.3411, -0.4322, -0.4302],
#           [-0.4056, -0.1785, -0.1177,  ..., -0.3504, -0.4287, -0.5113]],
#
#          [[ 0.1612, -0.0154, -0.3412,  ..., -0.5125, -0.5159, -0.1639],
#           [ 0.4233, -0.3820, -0.7082,  ..., -0.3246, -0.4419, -0.3003],
#           [ 0.2085, -0.3810, -0.2272,  ..., -0.2716, -0.4709, -0.2735],
#           ...,
#           [-0.3927, -0.1467,  0.0458,  ..., -0.3392, -0.2695, -0.2778],
#           [-0.2997, -0.0751, -0.0812,  ..., -0.2974, -0.3881, -0.3953],
#           [-0.1350, -0.1219, -0.0390,  ..., -0.3529, -0.3641, -0.4688]],
#
#          [[ 0.1428, -0.1005, -0.3641,  ..., -0.2814, -0.4351, -0.0850],
#           [ 0.3227, -0.4497, -0.8445,  ..., -0.2699, -0.3957, -0.2212],
#           [ 0.0403, -0.6109, -0.4984,  ..., -0.2848, -0.4050, -0.1643],
#           ...,
#           [-0.4028, -0.2351,  0.0349,  ..., -0.2722, -0.2271, -0.2221],
#           [-0.4158, -0.2045, -0.1124,  ..., -0.2902, -0.3421, -0.3382],
#           [-0.3098, -0.2569, -0.1520,  ..., -0.3287, -0.3751, -0.4253]]],
#
#
#         ...,
#
#
#         [[[ 0.9338,  0.8915,  0.9452,  ...,  0.9423,  1.0143,  1.0681],
#           [ 1.0347,  1.0028,  1.0428,  ...,  0.9843,  0.9729,  0.9994],
#           [ 0.9827,  1.0049,  0.9410,  ...,  1.0238,  1.0235,  0.9945],
#           ...,
#           [ 0.8612,  0.9287,  0.8906,  ...,  0.9689,  1.0227,  1.1300],
#           [ 0.9719,  0.9301,  1.0153,  ...,  1.0385,  1.0283,  1.0163],
#           [ 0.8973,  0.9708,  0.9228,  ...,  1.0424,  0.9695,  1.1179]],
#
#          [[ 0.8693,  0.8863,  0.8287,  ...,  0.9767,  0.9816,  1.0381],
#           [ 1.0681,  1.0538,  0.9311,  ...,  0.9837,  1.0067,  1.0082],
#           [ 1.0148,  1.0307,  0.9891,  ...,  0.9639,  1.0394,  1.0729],
#           ...,
#           [ 0.9388,  0.9476,  0.9667,  ...,  0.9932,  1.0291,  0.9896],
#           [ 0.8944,  0.9619,  0.9207,  ...,  0.9776,  1.0057,  0.9789],
#           [ 1.0894,  0.9017,  0.8900,  ...,  0.9814,  0.9340,  1.0521]],
#
#          [[ 0.9593,  0.9311,  0.9060,  ...,  1.0220,  0.9091,  1.1200],
#           [ 0.9739,  0.9822,  1.0491,  ...,  1.0456,  0.9599,  1.0315],
#           [ 0.9833,  1.0084,  0.9904,  ...,  1.0000,  0.9763,  0.9337],
#           ...,
#           [ 0.9117,  0.9685,  0.9068,  ...,  0.9921,  0.9867,  0.9920],
#           [ 0.9601,  0.9258,  0.9605,  ...,  0.9996,  0.9276,  1.0501],
#           [ 0.9763,  0.8863,  0.9694,  ...,  0.9726,  1.0379,  1.0831]]],
#
#
#         [[[-0.8871, -0.8493, -0.7862,  ...,  0.8248,  0.7184,  0.7827],
#           [-0.8805, -0.8807, -0.8520,  ...,  0.7578,  0.7730,  0.7986],
#           [-0.8664, -0.8998, -0.9434,  ...,  0.7408,  0.7507,  0.7832],
#           ...,
#           [ 0.7788,  0.5527, -0.0153,  ...,  0.4374,  0.4241,  0.2063],
#           [ 0.7300,  0.3327,  0.0259,  ...,  0.3931,  0.3450,  0.3432],
#           [ 0.3603,  0.2890,  0.2091,  ...,  0.4361,  0.5305,  0.4203]],
#
#          [[-0.0350, -0.1268, -0.1451,  ...,  0.7823,  0.7299,  0.7781],
#           [-0.1184, -0.1865, -0.1206,  ...,  0.8133,  0.7823,  0.7808],
#           [-0.1151, -0.1697, -0.2204,  ...,  0.7817,  0.7967,  0.7518],
#           ...,
#           [ 0.1789, -0.0432, -0.3715,  ...,  0.1723,  0.0963, -0.0424],
#           [ 0.2352, -0.0471, -0.3851,  ...,  0.2276,  0.1782,  0.0972],
#           [ 0.1217, -0.0077, -0.3299,  ...,  0.2887,  0.3482,  0.3162]],
#
#          [[ 0.5330,  0.5207,  0.4225,  ...,  0.7338,  0.7609,  0.7181],
#           [ 0.5715,  0.5025,  0.5299,  ...,  0.7563,  0.7716,  0.7334],
#           [ 0.5410,  0.5871,  0.5045,  ...,  0.7870,  0.7669,  0.8015],
#           ...,
#           [ 0.4797,  0.3571,  0.0413,  ...,  0.4773,  0.3296,  0.3076],
#           [ 0.4858,  0.2027,  0.0372,  ...,  0.4871,  0.4252,  0.3570],
#           [ 0.3483,  0.2039,  0.0981,  ...,  0.4498,  0.5404,  0.4488]]],
#
#
#         [[[-0.8413, -0.9339, -0.9606,  ..., -0.8733, -0.9265, -0.8498],
#           [-0.9607, -0.9394, -0.9072,  ..., -0.9178, -0.8686, -0.9098],
#           [-0.9908, -0.9858, -0.9239,  ..., -0.9207, -0.9329, -1.0126],
#           ...,
#           [-1.0039, -0.9283, -0.9516,  ..., -0.9833, -0.9347, -1.0442],
#           [-0.9707, -0.9567, -0.9668,  ..., -1.0185, -0.9883, -1.0065],
#           [-1.0591, -0.9322, -0.9925,  ..., -0.9598, -1.0119, -1.0011]],
#
#          [[-1.0139, -0.9743, -0.9819,  ..., -0.8423, -0.8807, -1.0334],
#           [-0.9890, -0.9610, -0.9997,  ..., -0.9325, -0.9167, -0.8254],
#           [-1.0158, -0.9938, -0.9354,  ..., -0.9148, -0.9190, -0.9432],
#           ...,
#           [-0.9068, -0.9351, -0.8884,  ..., -0.9702, -1.0244, -1.0734],
#           [-0.8772, -0.9362, -0.8735,  ..., -1.0195, -0.9920, -1.0208],
#           [-0.8127, -0.9724, -0.8914,  ..., -1.0042, -1.0584, -1.1286]],
#
#          [[-0.7462, -0.7088, -0.6618,  ..., -0.8082, -0.7971, -0.8982],
#           [-0.6641, -0.6276, -0.6811,  ..., -0.7967, -0.8799, -0.7424],
#           [-0.6738, -0.6858, -0.6689,  ..., -0.8942, -0.8434, -0.8236],
#           ...,
#           [-0.7838, -0.7567, -0.8075,  ..., -0.7381, -0.8087, -0.8745],
#           [-0.7200, -0.7440, -0.7251,  ..., -0.7111, -0.7998, -0.8133],
#           [-0.7832, -0.6836, -0.7207,  ..., -0.8478, -0.8787, -0.9088]]]],
#        device='cuda:3')

# %%
from helper.util import inception_score
from datasets.cifar100 import CIFAR100Gen
import torchvision.transforms as T
if not opt.save_grid:
    test_folder = opt.save_dir
    dataset = CIFAR100Gen(
        root=test_folder,
        transform=T.Compose([
            T.ToTensor(),
            T.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
        ])
    )
    mean, var = inception_score(dataset, device, resize=True, splits=3, batch_size=8)
    print(mean, var)
    
# print(os.listdir(test_folder))
print(len(os.listdir(test_folder)))
# Out:
# /data/lijingru/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/functional.py:3454: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# 7.011867473433784 0.02663938317507699
# 9998

# %%
os.listdir(test_folder)
# Out:
# ['samples_label_8_60.png',
#  'samples_label_17_11.png',
#  'samples_label_55_37.png',
#  'samples_label_1_65.png',
#  'samples_label_98_15.png',
#  'samples_label_66_81.png',
#  'samples_label_6_60.png',
#  'samples_label_91_34.png',
#  'samples_label_31_22.png',
#  'samples_label_7_73.png',
#  'samples_label_5_20.png',
#  'samples_label_14_13.png',
#  'samples_label_75_56.png',
#  'samples_label_26_15.png',
#  'samples_label_97_31.png',
#  'samples_label_52_74.png',
#  'samples_label_81_73.png',
#  'samples_label_69_60.png',
#  'samples_label_41_20.png',
#  'samples_label_52_22.png',
#  'samples_label_43_123.png',
#  'samples_label_92_31.png',
#  'samples_label_87_61.png',
#  'samples_label_29_15.png',
#  'samples_label_94_27.png',
#  'samples_label_99_49.png',
#  'samples_label_95_66.png',
#  'samples_label_56_68.png',
#  'samples_label_81_53.png',
#  'samples_label_62_68.png',
#  'samples_label_32_78.png',
#  'samples_label_17_7.png',
#  'samples_label_73_74.png',
#  'samples_label_81_58.png',
#  'samples_label_90_85.png',
#  'samples_label_53_35.png',
#  'samples_label_20_26.png',
#  'samples_label_42_56.png',
#  'samples_label_85_85.png',
#  'samples_label_67_50.png',
#  'samples_label_94_76.png',
#  'samples_label_79_17.png',
#  'samples_label_65_80.png',
#  'samples_label_43_118.png',
#  'samples_label_0_42.png',
#  'samples_label_6_47.png',
#  'samples_label_37_16.png',
#  'samples_label_11_33.png',
#  'samples_label_57_50.png',
#  'samples_label_18_82.png',
#  'samples_label_72_71.png',
#  'samples_label_75_14.png',
#  'samples_label_1_105.png',
#  'samples_label_11_13.png',
#  'samples_label_97_42.png',
#  'samples_label_92_19.png',
#  'samples_label_25_32.png',
#  'samples_label_98_37.png',
#  'samples_label_93_20.png',
#  'samples_label_8_21.png',
#  'samples_label_37_14.png',
#  'samples_label_73_56.png',
#  'samples_label_82_16.png',
#  'samples_label_2_62.png',
#  'samples_label_93_28.png',
#  'samples_label_41_60.png',
#  'samples_label_34_33.png',
#  'samples_label_25_60.png',
#  'samples_label_65_49.png',
#  'samples_label_56_89.png',
#  'samples_label_70_0.png',
#  'samples_label_21_65.png',
#  'samples_label_47_1.png',
#  'samples_label_87_66.png',
#  'samples_label_45_6.png',
#  'samples_label_72_30.png',
#  'samples_label_71_28.png',
#  'samples_label_40_53.png',
#  'samples_label_39_57.png',
#  'samples_label_2_98.png',
#  'samples_label_42_5.png',
#  'samples_label_90_64.png',
#  'samples_label_15_7.png',
#  'samples_label_17_33.png',
#  'samples_label_37_79.png',
#  'samples_label_62_73.png',
#  'samples_label_18_104.png',
#  'samples_label_28_57.png',
#  'samples_label_85_88.png',
#  'samples_label_21_2.png',
#  'samples_label_9_33.png',
#  'samples_label_11_53.png',
#  'samples_label_47_49.png',
#  'samples_label_47_10.png',
#  'samples_label_41_114.png',
#  'samples_label_20_7.png',
#  'samples_label_43_153.png',
#  'samples_label_1_39.png',
#  'samples_label_21_72.png',
#  'samples_label_22_10.png',
#  'samples_label_58_66.png',
#  'samples_label_75_61.png',
#  'samples_label_61_37.png',
#  'samples_label_8_56.png',
#  'samples_label_54_20.png',
#  'samples_label_65_125.png',
#  'samples_label_19_43.png',
#  'samples_label_21_106.png',
#  'samples_label_29_31.png',
#  'samples_label_58_20.png',
#  'samples_label_65_79.png',
#  'samples_label_43_1.png',
#  'samples_label_64_36.png',
#  'samples_label_82_17.png',
#  'samples_label_15_57.png',
#  'samples_label_72_34.png',
#  'samples_label_60_69.png',
#  'samples_label_6_35.png',
#  'samples_label_85_7.png',
#  'samples_label_47_70.png',
#  'samples_label_15_56.png',
#  'samples_label_87_5.png',
#  'samples_label_98_82.png',
#  'samples_label_55_44.png',
#  'samples_label_71_69.png',
#  'samples_label_42_41.png',
#  'samples_label_3_95.png',
#  'samples_label_24_30.png',
#  'samples_label_79_16.png',
#  'samples_label_15_72.png',
#  'samples_label_58_93.png',
#  'samples_label_55_25.png',
#  'samples_label_66_18.png',
#  'samples_label_19_45.png',
#  'samples_label_83_51.png',
#  'samples_label_97_11.png',
#  'samples_label_60_42.png',
#  'samples_label_8_37.png',
#  'samples_label_81_76.png',
#  'samples_label_73_79.png',
#  'samples_label_97_27.png',
#  'samples_label_11_50.png',
#  'samples_label_94_84.png',
#  'samples_label_1_43.png',
#  'samples_label_96_36.png',
#  'samples_label_31_1.png',
#  'samples_label_13_57.png',
#  'samples_label_10_27.png',
#  'samples_label_6_37.png',
#  'samples_label_24_90.png',
#  'samples_label_99_58.png',
#  'samples_label_40_59.png',
#  'samples_label_31_61.png',
#  'samples_label_87_54.png',
#  'samples_label_45_9.png',
#  'samples_label_80_33.png',
#  'samples_label_11_4.png',
#  'samples_label_24_72.png',
#  'samples_label_51_62.png',
#  'samples_label_71_86.png',
#  'samples_label_58_48.png',
#  'samples_label_2_41.png',
#  'samples_label_7_29.png',
#  'samples_label_90_84.png',
#  'samples_label_86_35.png',
#  'samples_label_53_13.png',
#  'samples_label_19_70.png',
#  'samples_label_42_39.png',
#  'samples_label_91_29.png',
#  'samples_label_11_67.png',
#  'samples_label_1_19.png',
#  'samples_label_85_40.png',
#  'samples_label_9_61.png',
#  'samples_label_82_77.png',
#  'samples_label_65_65.png',
#  'samples_label_24_62.png',
#  'samples_label_63_75.png',
#  'samples_label_1_18.png',
#  'samples_label_14_56.png',
#  'samples_label_43_2.png',
#  'samples_label_79_70.png',
#  'samples_label_97_58.png',
#  'samples_label_55_9.png',
#  'samples_label_93_75.png',
#  'samples_label_27_34.png',
#  'samples_label_87_41.png',
#  'samples_label_66_56.png',
#  'samples_label_3_44.png',
#  'samples_label_31_70.png',
#  'samples_label_65_88.png',
#  'samples_label_78_58.png',
#  'samples_label_56_81.png',
#  'samples_label_2_29.png',
#  'samples_label_57_35.png',
#  'samples_label_75_32.png',
#  'samples_label_35_4.png',
#  'samples_label_50_21.png',
#  'samples_label_33_9.png',
#  'samples_label_40_0.png',
#  'samples_label_10_83.png',
#  'samples_label_78_35.png',
#  'samples_label_85_71.png',
#  'samples_label_87_126.png',
#  'samples_label_38_50.png',
#  'samples_label_60_68.png',
#  'samples_label_18_22.png',
#  'samples_label_78_20.png',
#  'samples_label_82_18.png',
#  'samples_label_56_88.png',
#  'samples_label_54_23.png',
#  'samples_label_83_26.png',
#  'samples_label_38_61.png',
#  'samples_label_92_55.png',
#  'samples_label_96_76.png',
#  'samples_label_37_2.png',
#  'samples_label_69_50.png',
#  'samples_label_94_24.png',
#  'samples_label_56_57.png',
#  'samples_label_22_78.png',
#  'samples_label_38_70.png',
#  'samples_label_83_62.png',
#  'samples_label_37_77.png',
#  'samples_label_19_89.png',
#  'samples_label_60_1.png',
#  'samples_label_99_41.png',
#  'samples_label_14_2.png',
#  'samples_label_87_64.png',
#  'samples_label_84_73.png',
#  'samples_label_36_61.png',
#  'samples_label_67_13.png',
#  'samples_label_75_108.png',
#  'samples_label_86_32.png',
#  'samples_label_38_29.png',
#  'samples_label_35_67.png',
#  'samples_label_89_61.png',
#  'samples_label_9_48.png',
#  'samples_label_77_43.png',
#  'samples_label_12_75.png',
#  'samples_label_18_68.png',
#  'samples_label_8_55.png',
#  'samples_label_81_16.png',
#  'samples_label_59_46.png',
#  'samples_label_69_30.png',
#  'samples_label_36_95.png',
#  'samples_label_24_21.png',
#  'samples_label_85_58.png',
#  'samples_label_7_6.png',
#  'samples_label_98_94.png',
#  'samples_label_55_112.png',
#  'samples_label_84_69.png',
#  'samples_label_83_17.png',
#  'samples_label_55_147.png',
#  'samples_label_39_47.png',
#  'samples_label_47_7.png',
#  'samples_label_64_18.png',
#  'samples_label_91_8.png',
#  'samples_label_42_13.png',
#  'samples_label_61_68.png',
#  'samples_label_52_4.png',
#  'samples_label_7_96.png',
#  'samples_label_46_56.png',
#  'samples_label_43_159.png',
#  'samples_label_20_66.png',
#  'samples_label_96_108.png',
#  'samples_label_23_14.png',
#  'samples_label_9_5.png',
#  'samples_label_17_25.png',
#  'samples_label_34_46.png',
#  'samples_label_75_49.png',
#  'samples_label_16_41.png',
#  'samples_label_62_30.png',
#  'samples_label_27_66.png',
#  'samples_label_19_46.png',
#  'samples_label_81_41.png',
#  'samples_label_32_37.png',
#  'samples_label_1_101.png',
#  'samples_label_76_80.png',
#  'samples_label_86_8.png',
#  'samples_label_78_93.png',
#  'samples_label_33_3.png',
#  'samples_label_99_8.png',
#  'samples_label_23_46.png',
#  'samples_label_77_12.png',
#  'samples_label_45_46.png',
#  'samples_label_36_19.png',
#  'samples_label_54_41.png',
#  'samples_label_61_58.png',
#  'samples_label_98_83.png',
#  'samples_label_82_62.png',
#  'samples_label_65_35.png',
#  'samples_label_8_36.png',
#  'samples_label_75_54.png',
#  'samples_label_56_5.png',
#  'samples_label_89_8.png',
#  'samples_label_11_24.png',
#  'samples_label_46_8.png',
#  'samples_label_16_27.png',
#  'samples_label_20_92.png',
#  'samples_label_0_31.png',
#  'samples_label_65_139.png',
#  'samples_label_8_75.png',
#  'samples_label_1_9.png',
#  'samples_label_37_32.png',
#  'samples_label_90_14.png',
#  'samples_label_23_21.png',
#  'samples_label_38_9.png',
#  'samples_label_29_13.png',
#  'samples_label_95_52.png',
#  'samples_label_28_13.png',
#  'samples_label_41_61.png',
#  'samples_label_12_79.png',
#  'samples_label_1_80.png',
#  'samples_label_56_8.png',
#  'samples_label_57_54.png',
#  'samples_label_45_73.png',
#  'samples_label_57_2.png',
#  'samples_label_1_14.png',
#  'samples_label_82_27.png',
#  'samples_label_59_10.png',
#  'samples_label_6_75.png',
#  'samples_label_89_4.png',
#  'samples_label_5_92.png',
#  'samples_label_58_53.png',
#  'samples_label_79_1.png',
#  'samples_label_5_64.png',
#  'samples_label_72_68.png',
#  'samples_label_55_66.png',
#  'samples_label_79_87.png',
#  'samples_label_16_23.png',
#  'samples_label_95_18.png',
#  'samples_label_45_58.png',
#  'samples_label_43_14.png',
#  'samples_label_59_86.png',
#  'samples_label_75_0.png',
#  'samples_label_80_75.png',
#  'samples_label_67_15.png',
#  'samples_label_97_64.png',
#  'samples_label_94_94.png',
#  'samples_label_25_10.png',
#  'samples_label_97_85.png',
#  'samples_label_65_131.png',
#  'samples_label_99_42.png',
#  'samples_label_65_118.png',
#  'samples_label_6_14.png',
#  'samples_label_26_67.png',
#  'samples_label_67_77.png',
#  'samples_label_61_18.png',
#  'samples_label_54_52.png',
#  'samples_label_38_52.png',
#  'samples_label_99_17.png',
#  'samples_label_94_34.png',
#  'samples_label_0_84.png',
#  'samples_label_65_92.png',
#  'samples_label_90_61.png',
#  'samples_label_75_6.png',
#  'samples_label_2_116.png',
#  'samples_label_3_65.png',
#  'samples_label_41_95.png',
#  'samples_label_52_59.png',
#  'samples_label_5_36.png',
#  'samples_label_58_11.png',
#  'samples_label_43_65.png',
#  'samples_label_59_22.png',
#  'samples_label_87_27.png',
#  'samples_label_47_59.png',
#  'samples_label_23_56.png',
#  'samples_label_94_80.png',
#  'samples_label_59_80.png',
#  'samples_label_86_51.png',
#  'samples_label_12_83.png',
#  'samples_label_78_57.png',
#  'samples_label_3_34.png',
#  'samples_label_61_15.png',
#  'samples_label_93_58.png',
#  'samples_label_74_37.png',
#  'samples_label_84_5.png',
#  'samples_label_68_73.png',
#  'samples_label_90_6.png',
#  'samples_label_46_3.png',
#  'samples_label_20_63.png',
#  'samples_label_6_51.png',
#  'samples_label_75_95.png',
#  'samples_label_65_6.png',
#  'samples_label_86_28.png',
#  'samples_label_86_56.png',
#  'samples_label_6_78.png',
#  'samples_label_20_12.png',
#  'samples_label_9_40.png',
#  'samples_label_97_44.png',
#  'samples_label_27_8.png',
#  'samples_label_79_46.png',
#  'samples_label_72_77.png',
#  'samples_label_98_119.png',
#  'samples_label_15_27.png',
#  'samples_label_9_34.png',
#  'samples_label_17_35.png',
#  'samples_label_57_4.png',
#  'samples_label_81_37.png',
#  'samples_label_38_95.png',
#  'samples_label_21_88.png',
#  'samples_label_31_58.png',
#  'samples_label_38_13.png',
#  'samples_label_19_93.png',
#  'samples_label_77_18.png',
#  'samples_label_34_53.png',
#  'samples_label_36_54.png',
#  'samples_label_58_6.png',
#  'samples_label_73_35.png',
#  'samples_label_66_50.png',
#  'samples_label_9_43.png',
#  'samples_label_74_6.png',
#  'samples_label_99_13.png',
#  'samples_label_15_37.png',
#  'samples_label_75_4.png',
#  'samples_label_68_32.png',
#  'samples_label_12_14.png',
#  'samples_label_16_94.png',
#  'samples_label_53_75.png',
#  'samples_label_66_83.png',
#  'samples_label_99_4.png',
#  'samples_label_11_14.png',
#  'samples_label_47_30.png',
#  'samples_label_68_43.png',
#  'samples_label_20_17.png',
#  'samples_label_58_43.png',
#  'samples_label_13_5.png',
#  'samples_label_17_78.png',
#  'samples_label_5_12.png',
#  'samples_label_86_70.png',
#  'samples_label_93_34.png',
#  'samples_label_31_92.png',
#  'samples_label_34_23.png',
#  'samples_label_66_72.png',
#  'samples_label_80_15.png',
#  'samples_label_84_41.png',
#  'samples_label_23_94.png',
#  'samples_label_5_7.png',
#  'samples_label_85_31.png',
#  'samples_label_42_9.png',
#  'samples_label_24_17.png',
#  'samples_label_7_46.png',
#  'samples_label_42_44.png',
#  'samples_label_98_16.png',
#  'samples_label_17_47.png',
#  'samples_label_9_65.png',
#  'samples_label_55_29.png',
#  'samples_label_16_17.png',
#  'samples_label_7_55.png',
#  'samples_label_83_6.png',
#  'samples_label_27_59.png',
#  'samples_label_74_38.png',
#  'samples_label_8_39.png',
#  'samples_label_95_96.png',
#  'samples_label_88_67.png',
#  'samples_label_95_38.png',
#  'samples_label_32_55.png',
#  'samples_label_38_127.png',
#  'samples_label_79_51.png',
#  'samples_label_75_65.png',
#  'samples_label_97_66.png',
#  'samples_label_8_19.png',
#  'samples_label_16_24.png',
#  'samples_label_74_71.png',
#  'samples_label_91_79.png',
#  'samples_label_53_79.png',
#  'samples_label_20_68.png',
#  'samples_label_2_114.png',
#  'samples_label_45_44.png',
#  'samples_label_92_41.png',
#  'samples_label_11_1.png',
#  'samples_label_54_56.png',
#  'samples_label_76_94.png',
#  'samples_label_70_64.png',
#  'samples_label_32_51.png',
#  'samples_label_0_43.png',
#  'samples_label_53_133.png',
#  'samples_label_18_111.png',
#  'samples_label_76_21.png',
#  'samples_label_54_63.png',
#  'samples_label_24_96.png',
#  'samples_label_44_38.png',
#  'samples_label_59_38.png',
#  'samples_label_30_21.png',
#  'samples_label_65_91.png',
#  'samples_label_71_7.png',
#  'samples_label_93_16.png',
#  'samples_label_1_75.png',
#  'samples_label_78_86.png',
#  'samples_label_74_76.png',
#  'samples_label_5_59.png',
#  'samples_label_58_45.png',
#  'samples_label_60_2.png',
#  'samples_label_21_39.png',
#  'samples_label_45_22.png',
#  'samples_label_98_32.png',
#  'samples_label_69_10.png',
#  'samples_label_39_8.png',
#  'samples_label_56_80.png',
#  'samples_label_73_15.png',
#  'samples_label_27_10.png',
#  'samples_label_93_39.png',
#  'samples_label_43_188.png',
#  'samples_label_42_28.png',
#  'samples_label_48_9.png',
#  'samples_label_18_65.png',
#  'samples_label_66_86.png',
#  'samples_label_97_100.png',
#  'samples_label_95_13.png',
#  'samples_label_44_50.png',
#  'samples_label_49_53.png',
#  'samples_label_56_60.png',
#  'samples_label_33_4.png',
#  'samples_label_6_29.png',
#  'samples_label_71_73.png',
#  'samples_label_28_59.png',
#  'samples_label_95_56.png',
#  'samples_label_7_28.png',
#  'samples_label_33_50.png',
#  'samples_label_97_65.png',
#  'samples_label_78_40.png',
#  'samples_label_92_46.png',
#  'samples_label_38_138.png',
#  'samples_label_65_90.png',
#  'samples_label_12_1.png',
#  'samples_label_59_72.png',
#  'samples_label_47_55.png',
#  'samples_label_16_64.png',
#  'samples_label_47_44.png',
#  'samples_label_38_44.png',
#  'samples_label_47_66.png',
#  'samples_label_72_9.png',
#  'samples_label_23_85.png',
#  'samples_label_32_30.png',
#  'samples_label_56_90.png',
#  'samples_label_46_57.png',
#  'samples_label_92_9.png',
#  'samples_label_48_70.png',
#  'samples_label_9_26.png',
#  'samples_label_23_16.png',
#  'samples_label_39_20.png',
#  'samples_label_58_33.png',
#  'samples_label_82_31.png',
#  'samples_label_84_2.png',
#  'samples_label_12_98.png',
#  'samples_label_1_77.png',
#  'samples_label_24_81.png',
#  'samples_label_43_62.png',
#  'samples_label_3_33.png',
#  'samples_label_78_46.png',
#  'samples_label_53_145.png',
#  'samples_label_17_58.png',
#  'samples_label_15_28.png',
#  'samples_label_38_80.png',
#  'samples_label_92_11.png',
#  'samples_label_53_124.png',
#  'samples_label_26_46.png',
#  'samples_label_26_74.png',
#  'samples_label_80_58.png',
#  'samples_label_28_41.png',
#  'samples_label_85_9.png',
#  'samples_label_29_69.png',
#  'samples_label_46_60.png',
#  'samples_label_18_6.png',
#  'samples_label_10_9.png',
#  'samples_label_16_102.png',
#  'samples_label_27_12.png',
#  'samples_label_29_77.png',
#  'samples_label_88_41.png',
#  'samples_label_40_85.png',
#  'samples_label_73_33.png',
#  'samples_label_41_16.png',
#  'samples_label_17_8.png',
#  'samples_label_92_65.png',
#  'samples_label_74_77.png',
#  'samples_label_76_63.png',
#  'samples_label_30_86.png',
#  'samples_label_27_61.png',
#  'samples_label_88_86.png',
#  'samples_label_86_42.png',
#  'samples_label_85_97.png',
#  'samples_label_68_84.png',
#  'samples_label_13_1.png',
#  'samples_label_63_51.png',
#  'samples_label_30_5.png',
#  'samples_label_23_54.png',
#  'samples_label_38_39.png',
#  'samples_label_6_52.png',
#  'samples_label_79_79.png',
#  'samples_label_80_89.png',
#  'samples_label_56_31.png',
#  'samples_label_99_32.png',
#  'samples_label_31_27.png',
#  'samples_label_91_57.png',
#  'samples_label_22_57.png',
#  'samples_label_87_49.png',
#  'samples_label_58_71.png',
#  'samples_label_54_38.png',
#  'samples_label_87_109.png',
#  'samples_label_71_44.png',
#  'samples_label_29_14.png',
#  'samples_label_27_96.png',
#  'samples_label_84_64.png',
#  'samples_label_37_50.png',
#  'samples_label_63_64.png',
#  'samples_label_0_62.png',
#  'samples_label_0_24.png',
#  'samples_label_60_40.png',
#  'samples_label_62_26.png',
#  'samples_label_87_23.png',
#  'samples_label_99_59.png',
#  'samples_label_48_54.png',
#  'samples_label_54_54.png',
#  'samples_label_7_87.png',
#  'samples_label_41_41.png',
#  'samples_label_7_72.png',
#  'samples_label_63_21.png',
#  'samples_label_46_47.png',
#  'samples_label_56_9.png',
#  'samples_label_41_47.png',
#  'samples_label_11_20.png',
#  'samples_label_0_50.png',
#  'samples_label_51_4.png',
#  'samples_label_79_66.png',
#  'samples_label_49_10.png',
#  'samples_label_65_68.png',
#  'samples_label_84_31.png',
#  'samples_label_7_15.png',
#  'samples_label_95_95.png',
#  'samples_label_84_82.png',
#  'samples_label_78_60.png',
#  'samples_label_10_62.png',
#  'samples_label_44_3.png',
#  'samples_label_18_13.png',
#  'samples_label_0_34.png',
#  'samples_label_6_61.png',
#  'samples_label_80_14.png',
#  'samples_label_15_51.png',
#  'samples_label_75_82.png',
#  'samples_label_96_65.png',
#  'samples_label_15_1.png',
#  'samples_label_3_87.png',
#  'samples_label_44_34.png',
#  'samples_label_54_71.png',
#  'samples_label_87_114.png',
#  'samples_label_22_22.png',
#  'samples_label_81_15.png',
#  'samples_label_48_71.png',
#  'samples_label_52_40.png',
#  'samples_label_36_15.png',
#  'samples_label_37_69.png',
#  'samples_label_84_45.png',
#  'samples_label_41_36.png',
#  'samples_label_24_42.png',
#  'samples_label_14_40.png',
#  'samples_label_48_47.png',
#  'samples_label_81_97.png',
#  'samples_label_79_88.png',
#  'samples_label_75_12.png',
#  'samples_label_27_0.png',
#  'samples_label_1_96.png',
#  'samples_label_68_3.png',
#  'samples_label_33_5.png',
#  'samples_label_77_65.png',
#  'samples_label_22_27.png',
#  'samples_label_88_19.png',
#  'samples_label_65_95.png',
#  'samples_label_69_39.png',
#  'samples_label_43_20.png',
#  'samples_label_66_15.png',
#  'samples_label_12_89.png',
#  'samples_label_3_17.png',
#  'samples_label_6_1.png',
#  'samples_label_14_82.png',
#  'samples_label_43_34.png',
#  'samples_label_75_42.png',
#  'samples_label_7_82.png',
#  'samples_label_85_39.png',
#  'samples_label_74_36.png',
#  'samples_label_93_79.png',
#  'samples_label_20_0.png',
#  'samples_label_73_3.png',
#  'samples_label_33_28.png',
#  'samples_label_80_61.png',
#  'samples_label_79_5.png',
#  'samples_label_67_69.png',
#  'samples_label_74_54.png',
#  'samples_label_91_33.png',
#  'samples_label_43_157.png',
#  'samples_label_78_7.png',
#  'samples_label_75_90.png',
#  'samples_label_3_63.png',
#  'samples_label_1_103.png',
#  'samples_label_63_59.png',
#  'samples_label_6_8.png',
#  'samples_label_34_69.png',
#  'samples_label_33_69.png',
#  'samples_label_1_10.png',
#  'samples_label_85_1.png',
#  'samples_label_70_49.png',
#  'samples_label_13_17.png',
#  'samples_label_89_77.png',
#  'samples_label_12_87.png',
#  'samples_label_93_2.png',
#  'samples_label_46_23.png',
#  'samples_label_78_47.png',
#  'samples_label_80_9.png',
#  'samples_label_80_26.png',
#  'samples_label_48_39.png',
#  'samples_label_14_73.png',
#  'samples_label_62_90.png',
#  'samples_label_2_67.png',
#  'samples_label_32_33.png',
#  'samples_label_25_93.png',
#  'samples_label_19_21.png',
#  'samples_label_26_72.png',
#  'samples_label_47_71.png',
#  'samples_label_58_14.png',
#  'samples_label_24_40.png',
#  'samples_label_58_60.png',
#  'samples_label_2_0.png',
#  'samples_label_15_73.png',
#  'samples_label_42_68.png',
#  'samples_label_76_85.png',
#  'samples_label_37_75.png',
#  'samples_label_13_0.png',
#  'samples_label_55_137.png',
#  'samples_label_75_99.png',
#  'samples_label_43_196.png',
#  'samples_label_63_74.png',
#  'samples_label_45_31.png',
#  'samples_label_33_10.png',
#  'samples_label_62_61.png',
#  'samples_label_20_16.png',
#  'samples_label_66_71.png',
#  'samples_label_94_78.png',
#  'samples_label_65_133.png',
#  'samples_label_86_50.png',
#  'samples_label_85_42.png',
#  'samples_label_85_65.png',
#  'samples_label_64_2.png',
#  'samples_label_74_80.png',
#  'samples_label_91_21.png',
#  'samples_label_89_6.png',
#  'samples_label_72_23.png',
#  'samples_label_91_90.png',
#  'samples_label_86_14.png',
#  'samples_label_85_30.png',
#  'samples_label_51_95.png',
#  'samples_label_58_35.png',
#  'samples_label_4_59.png',
#  'samples_label_86_72.png',
#  'samples_label_4_50.png',
#  'samples_label_22_54.png',
#  'samples_label_79_44.png',
#  'samples_label_61_1.png',
#  'samples_label_50_18.png',
#  'samples_label_27_68.png',
#  'samples_label_28_73.png',
#  'samples_label_83_64.png',
#  'samples_label_80_1.png',
#  'samples_label_22_81.png',
#  'samples_label_85_94.png',
#  'samples_label_20_93.png',
#  'samples_label_29_12.png',
#  'samples_label_49_92.png',
#  'samples_label_85_12.png',
#  'samples_label_53_86.png',
#  'samples_label_77_69.png',
#  'samples_label_48_76.png',
#  'samples_label_30_19.png',
#  'samples_label_29_56.png',
#  'samples_label_65_33.png',
#  'samples_label_33_1.png',
#  'samples_label_1_4.png',
#  'samples_label_3_70.png',
#  'samples_label_13_35.png',
#  'samples_label_94_41.png',
#  'samples_label_61_81.png',
#  'samples_label_62_84.png',
#  'samples_label_94_29.png',
#  'samples_label_32_100.png',
#  'samples_label_94_92.png',
#  'samples_label_91_0.png',
#  'samples_label_59_75.png',
#  'samples_label_21_16.png',
#  'samples_label_27_57.png',
#  'samples_label_29_9.png',
#  'samples_label_92_45.png',
#  'samples_label_75_79.png',
#  'samples_label_83_73.png',
#  'samples_label_94_79.png',
#  'samples_label_29_2.png',
#  'samples_label_87_127.png',
#  'samples_label_83_46.png',
#  'samples_label_89_17.png',
#  'samples_label_65_37.png',
#  'samples_label_77_48.png',
#  'samples_label_6_17.png',
#  'samples_label_55_30.png',
#  'samples_label_83_96.png',
#  'samples_label_12_38.png',
#  'samples_label_97_90.png',
#  'samples_label_47_75.png',
#  'samples_label_97_5.png',
#  'samples_label_2_57.png',
#  'samples_label_24_46.png',
#  'samples_label_39_0.png',
#  'samples_label_77_16.png',
#  'samples_label_69_17.png',
#  'samples_label_23_65.png',
#  'samples_label_98_30.png',
#  'samples_label_21_108.png',
#  'samples_label_94_81.png',
#  'samples_label_93_43.png',
#  'samples_label_66_3.png',
#  'samples_label_46_29.png',
#  'samples_label_86_61.png',
#  'samples_label_80_10.png',
#  'samples_label_5_18.png',
#  'samples_label_24_63.png',
#  'samples_label_88_50.png',
#  'samples_label_6_32.png',
#  'samples_label_31_78.png',
#  'samples_label_5_93.png',
#  'samples_label_53_104.png',
#  'samples_label_45_53.png',
#  'samples_label_80_74.png',
#  'samples_label_48_40.png',
#  'samples_label_95_48.png',
#  'samples_label_62_31.png',
#  'samples_label_27_92.png',
#  'samples_label_9_6.png',
#  'samples_label_35_71.png',
#  'samples_label_68_48.png',
#  'samples_label_97_24.png',
#  'samples_label_60_24.png',
#  'samples_label_96_102.png',
#  'samples_label_95_68.png',
#  'samples_label_18_62.png',
#  'samples_label_37_22.png',
#  'samples_label_33_85.png',
#  'samples_label_37_87.png',
#  'samples_label_24_89.png',
#  'samples_label_58_69.png',
#  'samples_label_32_19.png',
#  'samples_label_13_59.png',
#  'samples_label_84_11.png',
#  'samples_label_78_13.png',
#  'samples_label_44_23.png',
#  'samples_label_39_51.png',
#  'samples_label_94_3.png',
#  'samples_label_99_24.png',
#  'samples_label_43_0.png',
#  'samples_label_31_7.png',
#  'samples_label_15_47.png',
#  'samples_label_44_41.png',
#  'samples_label_86_74.png',
#  'samples_label_15_20.png',
#  'samples_label_38_144.png',
#  'samples_label_59_21.png',
#  'samples_label_5_47.png',
#  'samples_label_87_28.png',
#  'samples_label_41_28.png',
#  'samples_label_22_30.png',
#  'samples_label_30_10.png',
#  'samples_label_1_30.png',
#  'samples_label_14_35.png',
#  'samples_label_92_29.png',
#  'samples_label_78_54.png',
#  'samples_label_63_38.png',
#  'samples_label_78_64.png',
#  'samples_label_3_13.png',
#  'samples_label_64_69.png',
#  'samples_label_44_48.png',
#  'samples_label_3_81.png',
#  'samples_label_12_8.png',
#  'samples_label_58_79.png',
#  'samples_label_47_26.png',
#  'samples_label_45_75.png',
#  'samples_label_70_50.png',
#  'samples_label_62_58.png',
#  'samples_label_9_85.png',
#  'samples_label_83_5.png',
#  'samples_label_86_16.png',
#  'samples_label_34_36.png',
#  'samples_label_12_84.png',
#  'samples_label_95_62.png',
#  'samples_label_97_70.png',
#  'samples_label_3_6.png',
#  'samples_label_12_62.png',
#  'samples_label_37_6.png',
#  'samples_label_92_39.png',
#  'samples_label_46_18.png',
#  'samples_label_22_93.png',
#  'samples_label_48_61.png',
#  'samples_label_10_57.png',
#  'samples_label_2_2.png',
#  'samples_label_45_35.png',
#  'samples_label_71_23.png',
#  'samples_label_76_104.png',
#  'samples_label_6_74.png',
#  'samples_label_51_57.png',
#  'samples_label_51_55.png',
#  'samples_label_30_35.png',
#  'samples_label_23_92.png',
#  'samples_label_71_96.png',
#  'samples_label_1_68.png',
#  'samples_label_36_35.png',
#  'samples_label_38_85.png',
#  'samples_label_18_75.png',
#  'samples_label_84_47.png',
#  'samples_label_77_3.png',
#  'samples_label_22_9.png',
#  'samples_label_3_61.png',
#  'samples_label_80_77.png',
#  'samples_label_33_12.png',
#  'samples_label_84_91.png',
#  'samples_label_27_56.png',
#  'samples_label_2_96.png',
#  'samples_label_43_128.png',
#  'samples_label_11_21.png',
#  'samples_label_21_113.png',
#  'samples_label_64_20.png',
#  'samples_label_63_71.png',
#  'samples_label_80_29.png',
#  'samples_label_93_3.png',
#  'samples_label_72_28.png',
#  'samples_label_87_18.png',
#  'samples_label_62_33.png',
#  'samples_label_74_53.png',
#  'samples_label_76_50.png',
#  'samples_label_17_87.png',
#  'samples_label_55_120.png',
#  'samples_label_72_63.png',
#  'samples_label_1_63.png',
#  'samples_label_1_16.png',
#  'samples_label_17_96.png',
#  'samples_label_19_41.png',
#  'samples_label_46_54.png',
#  'samples_label_56_41.png',
#  'samples_label_59_59.png',
#  'samples_label_38_101.png',
#  'samples_label_14_68.png',
#  'samples_label_47_24.png',
#  'samples_label_87_4.png',
#  'samples_label_29_7.png',
#  'samples_label_13_33.png',
#  'samples_label_14_24.png',
#  'samples_label_48_63.png',
#  'samples_label_13_22.png',
#  'samples_label_71_93.png',
#  'samples_label_27_87.png',
#  'samples_label_77_9.png',
#  'samples_label_82_15.png',
#  'samples_label_46_7.png',
#  'samples_label_44_39.png',
#  'samples_label_30_66.png',
#  'samples_label_19_116.png',
#  'samples_label_91_54.png',
#  'samples_label_21_61.png',
#  'samples_label_38_124.png',
#  'samples_label_90_24.png',
#  'samples_label_81_102.png',
#  'samples_label_19_96.png',
#  'samples_label_53_96.png',
#  'samples_label_91_95.png',
#  'samples_label_55_10.png',
#  'samples_label_69_8.png',
#  'samples_label_77_5.png',
#  'samples_label_97_53.png',
#  'samples_label_53_82.png',
#  'samples_label_13_44.png',
#  'samples_label_64_14.png',
#  'samples_label_63_28.png',
#  'samples_label_58_32.png',
#  'samples_label_97_68.png',
#  'samples_label_29_60.png',
#  'samples_label_55_18.png',
#  'samples_label_33_63.png',
#  'samples_label_26_60.png',
#  'samples_label_36_79.png',
#  'samples_label_13_56.png',
#  'samples_label_50_16.png',
#  'samples_label_16_11.png',
#  'samples_label_35_41.png',
#  'samples_label_93_61.png',
#  'samples_label_43_4.png',
#  'samples_label_39_84.png',
#  'samples_label_67_51.png',
#  'samples_label_41_113.png',
#  'samples_label_15_105.png',
#  'samples_label_5_43.png',
#  'samples_label_36_83.png',
#  'samples_label_91_87.png',
#  'samples_label_30_7.png',
#  'samples_label_15_60.png',
#  'samples_label_74_64.png',
#  'samples_label_95_57.png',
#  'samples_label_13_2.png',
#  'samples_label_73_61.png',
#  ...]

# %%
# print(len(os.listdir(test_folder)))
from helper.util_gen import cond_samples
test_folder = opt.save_dir
print(test_folder)

optd = Options(save_grid=True)
cond_samples(model, replay_buffer, device, optd)
# Out:
# /data/lijingru/EBKD/save/student_model/resnet28x10_T:resnet32x4_S:resnet8x4_cifar10_lr_1e-05_decay_0.0_buffer_size_10000_lpx_1.0_lpxy_0.0_energy_mode_mcmc_step_size_1.0_trial_1_cls_mode_cls_k_10/img_sample_eval/
# 100%|██████████| 10/10 [00:02<00:00,  3.81it/s]
# Successfully saving the generated result of replay buffer.
# Successfully save the result.

# %% [markdown]
# ### t-SNE visualization

# %% [markdown]
# ## Set options, datasets and dataloaders

# %%
from datasets.cifar100 import CIFAR100Gen, CIFAR100Instance
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from PIL import Image

test_folder = '/data/lijingru/cifar100/'
test_gen_folder = '/data/lijingru/img_sample_eval/'


test_list = [
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
]


# train_transform = transforms.Compose(train_list)
test_transform = transforms.Compose(test_list)
test_positive_set = CIFAR100Instance(root=test_folder, download=True, train=False, transform=test_transform)
test_negative_set = CIFAR100Gen(root=opt.save_dir, transform=test_transform, return_target=True)

test_p_loader = DataLoader(dataset=test_positive_set, batch_size=1, shuffle=False, num_workers=8)
test_n_loader = DataLoader(dataset=test_negative_set, batch_size=1, shuffle=False, num_workers=8)
# Out:
# Files already downloaded and verified

# %%
import tqdm
model.eval()
p_energys = []
q_energys = []
correct = 0
p_predict = []
for idx, data in tqdm.tqdm(enumerate(test_p_loader)):
    x, y, i = data
    x = x.to(device)
    y = y.to(device)
    logit = model(x=x, cls_mode=True)
    indexs = torch.argmax(logit, 1)
    p_predict += indexs.tolist()
    b_correct = torch.sum(indexs == y).item()
    correct += b_correct
    f = torch.gather(logit, 1, y[:, None]).mean()
    
    f = model(x=x, y=y)[0].mean()
    p_energys.append(f.item())
    
print('Positive Samples:')
print('Max: {:.4f}'.format(max(p_energys)))
print('Min: {:.4f}'.format(min(p_energys)))
print('Mean: {:.4f}'.format(sum(p_energys) / len(p_energys)))
print('Acc: {:.4f}'.format(correct / len(test_p_loader)))

for idx, data in tqdm.tqdm(enumerate(test_n_loader)):
    x, y, i = data
    x = x.to(device)
    y = y.to(device)
    
    f = model(x=x, y=y)[0].mean()
    q_energys.append(f.item())
    


print('Negative Samples:')
print('Max: {:.4f}'.format(max(q_energys)))
print('Min: {:.4f}'.format(min(q_energys)))
print('Mean: {:.4f}'.format(sum(q_energys) / len(q_energys)))
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-a254265cf055> in <module>
#      16     f = torch.gather(logit, 1, y[:, None]).mean()
#      17
# ---> 18     f = model(x=x, y=y)[0].mean()
#      19     p_energys.append(f.item())
#      20
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/EBKD/models/generator.py in forward(self, x, y, cls_mode, is_feat, preact, py)
#      75         #print(cls_mode, is_feat, preact, y)
#      76
# ---> 77         feats, logits = super().classify(x, is_feat=True, preact=preact)
#      78
#      79         # feat = feats[-1]
#
# ~/EBKD/models/generator.py in classify(self, x, is_feat, preact)
#      48     def classify(self, x, is_feat=False, preact=False):
#      49         if is_feat:
# ---> 50             feats, penult_z = self.f(x, is_feat=is_feat, preact=preact)
#      51             # print(penult_z.requires_grad)
#      52             # print(self.f(x, is_feat=is_feat, preact=preact))
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/EBKD/models/widerresnet.py in forward(self, x, vx, is_feat, preact)
#     125         f1 = self.conv1(x)
#     126         f2 = self.layer1(f1)
# --> 127         f3 = self.layer2(f2)
#     128         f4 = self.layer3(f3)
#     129         out = self.lrelu(self.bn1(f4))
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/EBKD/models/widerresnet.py in forward(self, x)
#      66         # print(self.dropout, self.conv1, self.lrelu, self.bn1)
#      67         out = self.dropout(self.conv1(self.lrelu(self.bn1(x))))
# ---> 68         out = self.conv2(self.lrelu(self.bn2(out)))
#      69         out += self.shortcut(x)
#      70
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
# --> 399         return self._conv_forward(input, self.weight, self.bias)
#     400
#     401 class Conv3d(_ConvNd):
#
# ~/anaconda3/envs/torch/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     393                             weight, bias, self.stride,
#     394                             _pair(0), self.dilation, self.groups)
# --> 395         return F.conv2d(input, weight, bias, self.stride,
#     396                         self.padding, self.dilation, self.groups)
#     397
#
# RuntimeError: cuDNN error: CUDNN_STATUS_EXECUTION_FAILED
# You can try to repro this exception using the following code snippet. If that doesn't trigger the error, please include your original repro script when reporting this issue.
#
# import torch
# torch.backends.cuda.matmul.allow_tf32 = True
# torch.backends.cudnn.benchmark = False
# torch.backends.cudnn.deterministic = False
# torch.backends.cudnn.allow_tf32 = True
# data = torch.randn([1, 320, 16, 16], dtype=torch.float, device='cuda', requires_grad=True)
# net = torch.nn.Conv2d(320, 320, kernel_size=[3, 3], padding=[1, 1], stride=[1, 1], dilation=[1, 1], groups=1)
# net = net.cuda().float()
# out = net(data)
# out.backward(torch.randn_like(out))
# torch.cuda.synchronize()
#
# ConvolutionParams
#     data_type = CUDNN_DATA_FLOAT
#     padding = [1, 1, 0]
#     stride = [1, 1, 0]
#     dilation = [1, 1, 0]
#     groups = 1
#     deterministic = false
#     allow_tf32 = true
# input: TensorDescriptor 0x55efd1d4a4e0
#     type = CUDNN_DATA_FLOAT
#     nbDims = 4
#     dimA = 1, 320, 16, 16,
#     strideA = 81920, 256, 16, 1,
# output: TensorDescriptor 0x55efd491d930
#     type = CUDNN_DATA_FLOAT
#     nbDims = 4
#     dimA = 1, 320, 16, 16,
#     strideA = 81920, 256, 16, 1,
# weight: FilterDescriptor 0x55efd1d584d0
#     type = CUDNN_DATA_FLOAT
#     tensor_format = CUDNN_TENSOR_NCHW
#     nbDims = 4
#     dimA = 320, 320, 3, 3,
# Pointer addresses:
#     input: 0x7f3977c50000
#     output: 0x7f3977ca0000
#     weight: 0x7f3a388ca000
# Forward algorithm: 6

# %%
np.save(os.path.join(opt.save_folder, 'pxy_energy.npy'), np.asarray(p_energys))
np.save(os.path.join(opt.save_folder, 'qxy_energy.npy'), np.asarray(q_energys))

# %% [markdown]
# ## Plot the distribution of energy function
# $x^+ \sim p_{data}$, and $x^- \sim q_{\theta}$. If the EBM is well-trained, the plotted distribution should be close enough.
#
# Here presented the distribution of conditional generation $p_{\theta}(x | y)$.

# %%
sns.kdeplot(data={'p':p_energys, 'q':q_energys}, clip=(-5, 5), fill=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(x=p_energys, kde=True, rug=True)

# %%
sns.displot(x=q_energys, color='orange', rug=True, kde=True)

# %%
sns.displot(x=p_predict)

# %% [markdown]
# ## Unconditional energy distribution
# Considering the distribution of unconditional generation $p_{\theta}(x)$.

# %%
model.eval()
p_energys = []
q_energys = []
for idx, data in tqdm.tqdm(enumerate(test_p_loader)):
    x, y, i = data
    x = x.to(device)
    y = y.to(device)
    
    f = model(x=x)[0].mean()
    p_energys.append(f.item())
    
print('Positive Samples:')
print('Max: {:.4f}'.format(max(p_energys)))
print('Min: {:.4f}'.format(min(p_energys)))
print('Mean: {:.4f}'.format(sum(p_energys) / len(p_energys)))

for idx, data in tqdm.tqdm(enumerate(test_n_loader)):
    x, y, i = data
    x = x.to(device)
    y = y.to(device)
    
    f = model(x=x)[0].mean()
    q_energys.append(f.item())
    


print('Negative Samples:')
print('Max: {:.4f}'.format(max(q_energys)))
print('Min: {:.4f}'.format(min(q_energys)))
print('Mean: {:.4f}'.format(sum(q_energys) / len(q_energys)))
# Out:
# 10000it [01:18, 127.25it/s]
# Positive Samples:
# Max: 8.8759
# Min: -10.3981
# Mean: 2.0606
# 10000it [01:18, 127.34it/s]
# Negative Samples:
# Max: 9.1379
# Min: -8.6306
# Mean: 2.3224

# %%
np.save(os.path.join(opt.save_folder, 'px_energy.npy'), np.asarray(p_energys))
np.save(os.path.join(opt.save_folder, 'qx_energy.npy'), np.asarray(q_energys))

# %%
sns.kdeplot(data={'p':p_energys, 'q':q_energys}, clip=(-5, 10), fill=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(x=p_energys, kde=True, rug=True)

# %%
sns.displot(x=q_energys, color='orange', rug=True, kde=True)

# %%
f = open(os.path.join(opt.save_folder, 'best.txt'), 'w')
f.write('best_result:{:.4f} +- {:.4f}'.format(mean, var))
f.close()
